# %%
# Import useful dependencies.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
plt.style.use("fivethirtyeight")
# %matplotlib inline

# For reading stock data from yahoo.

from pandas_datareader.data import DataReader
import yfinance as yf

# For time stamps.

from datetime import datetime
from datetime import date

# %%
# COVID 19 recession:
# Create an empty list to house the closing price for each sector, the list of sector names and the date on the eve of the recession.

eve_price=[]
sectors_title=["Energy", "Materials", "Industrials", "Consumer Disc", "Consumer Stap", "Health Care", "Financial", "Technology", "Communications", "Utilities", "Real Estate"]
eve_date_list=[]
end_date_list=[]

# %%
# COVID 19 recession:
# Extract the closing price for each sector on the eve of the recession and its corresponding date.

for sector in sectors_title:
    try:
        Price_Start = Combined_Sectors_df[f"{sector} Close"][0]
        eve_price.append(Price_Start)
        eve_date=Combined_Sectors_df["Date"][0]
        eve_date_list.append(eve_date)
        end_date_list.append(COVID_end)
    except KeyError:
        eve_price.append("No Data")
        
# Create a dataframe for Recession Start Dates, End Dates, Sector and Sector Price (eve of recession).

Eve_Sector_df=pd.DataFrame({"Recession Start":eve_date_list, "Recession End":end_date_list, "Sector":sectors_title, "Eve Price":eve_price})
Eve_Sector_df
# Out:
#    Recession Start Recession End          Sector    Eve Price
# 0       2020-01-31    2020-04-01          Energy   405.450012
# 1       2020-01-31    2020-04-01       Materials   361.989990
# 2       2020-01-31    2020-04-01     Industrials   684.119995
# 3       2020-01-31    2020-04-01   Consumer Disc   992.010010
# 4       2020-01-31    2020-04-01   Consumer Stap   648.250000
# 5       2020-01-31    2020-04-01     Health Care  1153.959961
# 6       2020-01-31    2020-04-01       Financial   497.100006
# 7       2020-01-31    2020-04-01      Technology  1673.910034
# 8       2020-01-31    2020-04-01  Communications   182.839996
# 9       2020-01-31    2020-04-01       Utilities   350.079987
# 10      2020-01-31    2020-04-01     Real Estate   243.619995

# %%
# COVID 19 recession:
# Examine all of the POST COVID 19 recession data:

COVID_end = datetime(2020,4,1)
Today_Date = datetime(2022,3,22)

sector_list = ['^GSPC','^SP500-40','^SP500-25','^SP500-30',"^SP500-35","^SP500-20","^SP500-45","^SP500-15","^SP500-60","^SP500-50","^SP500-55","^GSPE"]
sector_name = ["S_P500", "Financials","Consumer_Discretionary","Consumer_Staples","Health","Industrials","Information_Tech","Materials","Real_Estate","Tele_Services","Utilities","Energy"]
thisyear = ['^GSPC','^SP500-40','^SP500-25','^SP500-30',"^SP500-35","^SP500-20","^SP500-45","^SP500-15","^SP500-60","^SP500-50","^SP500-55","^GSPE"]

# Extract data for each sector from Yahoo Finance and export it to its own CSV file.

for sector in sector_list: 
    file_name=str(sector)+".csv"
    thisyear[sector_list.index(sector)] = globals()[sector] = yf.download(sector, COVID_end, Today_Date)
    thisyear[sector_list.index(sector)].to_csv(f"Post_COVID_Recession/{file_name}", index=True, header=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# COVID 19 recession:
# Establish paths for CSV import in next step.

Energy2 = "Post_COVID_Recession/^GSPE.csv"
Materials2 = "Post_COVID_Recession/^SP500-15.csv"
Industrials2 = "Post_COVID_Recession/^SP500-20.csv"
Consumer_Disc2 = "Post_COVID_Recession/^SP500-25.csv"
Consumer_Stap2 = "Post_COVID_Recession/^SP500-30.csv"
Health_Care2 = "Post_COVID_Recession/^SP500-35.csv"
Financial2 = "Post_COVID_Recession/^SP500-40.csv"
Technology2 = "Post_COVID_Recession/^SP500-45.csv"
Communications2 = "Post_COVID_Recession/^SP500-50.csv"
Utilities2 = "Post_COVID_Recession/^SP500-55.csv"
Real_Estate2 = "Post_COVID_Recession/^SP500-60.csv"


# Create a data frame for each sector using its CSV file.

Energy2_df = pd.read_csv(Energy2)
Materials2_df = pd.read_csv(Materials2)
Industrials2_df = pd.read_csv(Industrials2)
Consumer_Disc2_df = pd.read_csv(Consumer_Disc2)
Consumer_Stap2_df = pd.read_csv(Consumer_Stap2)
Health_Care2_df = pd.read_csv(Health_Care2)
Financial2_df = pd.read_csv(Financial2)
Technology2_df = pd.read_csv(Technology2)
Communications2_df = pd.read_csv(Communications2)
Utilities2_df = pd.read_csv(Utilities2)
Real_Estate2_df = pd.read_csv(Real_Estate2)


# Rename the column headers to avoid conflicts when merging data frames.

Energy2_Cleaned_df=Energy2_df.rename(columns={"Open":"Energy Open", "High": "Energy High", "Low": "Energy Low", "Close":"Energy Close", "Adj Close":"Adj Close Energy", "Volume":"Energy Volume"})
Materials2_Cleaned_df=Materials2_df.rename(columns={"Open":"Materials Open", "High": "Materials High", "Low": "Materials Low", "Close":"Materials Close", "Adj Close":"Adj Close Materials", "Volume":"Materials Volume"})
Industrials2_Cleaned_df=Industrials2_df.rename(columns={"Open":"Industrials Open", "High": "Industrials High", "Low": "Industrials Low", "Close":"Industrials Close", "Adj Close":"Adj Close Industrials", "Volume":"Industrials Volume"})
Consumer_Disc2_Cleaned_df=Consumer_Disc2_df.rename(columns={"Open":"Consumer Disc Open", "High": "Consumer Disc High", "Low": "Consumer Disc Low", "Close":"Consumer Disc Close", "Adj Close":"Adj Close Consumer Disc", "Volume":"Consumer Disc Volume"})
Consumer_Stap2_Cleaned_df=Consumer_Stap2_df.rename(columns={"Open":"Consumer Stap Open", "High": "Consumer Stap High", "Low": "Consumer Stap Low", "Close":"Consumer Stap Close", "Adj Close":"Adj Close Consumer Stap", "Volume":"Consumer Stap Volume"})
Health_Care2_Cleaned_df=Health_Care2_df.rename(columns={"Open":"Health Care Open", "High": "Health Care High", "Low": "Health Care Low", "Close":"Health Care Close", "Adj Close":"Adj Close Health Care", "Volume":"Health Care Volume"})
Financial2_Cleaned_df=Financial2_df.rename(columns={"Open":"Financial Open", "High": "Financial High", "Low": "Financial Low", "Close":"Financial Close", "Adj Close":"Adj Close Financial", "Volume":"Financial Volume"})
Technology2_Cleaned_df=Technology2_df.rename(columns={"Open":"Technology Open", "High": "Technology High", "Low": "Technology Low", "Close":"Technology Close", "Adj Close":"Adj Close Technology", "Volume":"Technology Volume"})
Communications2_Cleaned_df=Communications2_df.rename(columns={"Open":"Communications Open", "High": "Communications High", "Low": "Communications Low", "Close":"Communications Close", "Adj Close":"Adj Close Communications", "Volume":"Communications Volume"})
Utilities2_Cleaned_df=Utilities2_df.rename(columns={"Open":"Utilities Open", "High": "Utilities High", "Low": "Utilities Low", "Close":"Utilities Close", "Adj Close":"Adj Close Utilities", "Volume":"Utilities Volume"})
Real_Estate2_Cleaned_df=Real_Estate2_df.rename(columns={"Open":"Real Estate Open", "High": "Real Estate High", "Low": "Real Estate Low", "Close":"Real Estate Close", "Adj Close":"Adj Close Real Estate", "Volume":"Real Estate Volume"})


# Merge all sector data frames together using the DATE as the merge parameter.

combined1_df = pd.merge(Energy2_Cleaned_df, Materials2_Cleaned_df, how="left", on=["Date", "Date"])
combined2_df = pd.merge(combined1_df, Industrials2_Cleaned_df, how="left", on=["Date", "Date"])
combined3_df = pd.merge(combined2_df, Consumer_Disc2_Cleaned_df, how="left", on=["Date", "Date"])
combined4_df = pd.merge(combined3_df, Consumer_Stap2_Cleaned_df, how="left", on=["Date", "Date"])
combined5_df = pd.merge(combined4_df, Health_Care2_Cleaned_df, how="left", on=["Date", "Date"])
combined6_df = pd.merge(combined5_df, Financial2_Cleaned_df, how="left", on=["Date", "Date"])
combined7_df = pd.merge(combined6_df, Technology2_Cleaned_df, how="left", on=["Date", "Date"])
combined8_df = pd.merge(combined7_df, Communications2_Cleaned_df, how="left", on=["Date", "Date"])
combined9_df = pd.merge(combined8_df, Utilities2_Cleaned_df, how="left", on=["Date", "Date"])
Combined_Sectors2_df = pd.merge(combined9_df, Real_Estate2_Cleaned_df, how="left", on=["Date", "Date"])
Combined_Sectors2_df[["Date", "Energy Close", "Materials Close", "Industrials Close", "Consumer Disc Close", "Consumer Stap Close", "Health Care Close", "Financial Close", "Technology Close", "Communications Close", "Utilities Close", "Real Estate Close"]].head()
# Out:
#          Date  Energy Close  Materials Close  Industrials Close  \
# 0  2020-03-31    223.399994       283.230011         499.119995
# 1  2020-04-01    213.039993       270.220001         476.239990
# 2  2020-04-02    232.369995       274.269989         483.200012
# 3  2020-04-03    229.259995       267.859985         475.700012
# 4  2020-04-06    241.070007       288.230011         509.100006
#
#    Consumer Disc Close  Consumer Stap Close  Health Care Close  \
# 0           793.109985           560.330017        1032.900024
# 1           761.659973           550.080017         993.020020
# 2           764.320007           566.000000        1020.679993
# 3           753.090027           569.070007        1010.869995
# 4           811.309998           591.380005        1065.430054
#
#    Financial Close  Technology Close  Communications Close  Utilities Close  \
# 0       346.019989       1414.359985            150.350006       281.769989
# ...

# %%
# Create graphs showing the post COVID 19 recession performance of each sector. 

plt.figure(figsize=(15, 40))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, sector in enumerate(sector_list, 1):
    plt.subplot(11, 2, i)
    thisyear[i-1]['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {sector_name[i - 1]}")
plt.tight_layout()
plt.savefig(f"Adj Close Change by Sectors({COVID_start.year}).png")

# %%
# COVID 19 recession:
# Establish an empty list to house each sector's recovery date. 

recovery_dates=[]

# Analyse each sector's recovery.

# Energy:

Energy_Higher_Than_Eve_df=Combined_Sectors2_df.loc[Combined_Sectors2_df["Energy Close"]>= eve_price[0], :]
Energy_Recovery_First_Row=Energy_Higher_Than_Eve_df.iloc[0,:].tolist()
Energy_Recovery_Date=Energy_Recovery_First_Row[0]
recovery_dates.append(Energy_Recovery_Date)

# Materials

Materials_Higher_Than_Eve_df=Combined_Sectors2_df.loc[Combined_Sectors2_df["Materials Close"]>= eve_price[1], :]
Materials_Recovery_First_Row=Materials_Higher_Than_Eve_df.iloc[0,:].tolist()
Materials_Recovery_Date=Materials_Recovery_First_Row[0]
recovery_dates.append(Materials_Recovery_Date)

#Industrials

Industrials_Higher_Than_Eve_df=Combined_Sectors2_df.loc[Combined_Sectors2_df["Industrials Close"]>= eve_price[2], :]
Industrials_Recovery_First_Row=Industrials_Higher_Than_Eve_df.iloc[0,:].tolist()
Industrials_Recovery_Date=Industrials_Recovery_First_Row[0]
recovery_dates.append(Industrials_Recovery_Date)

#Consumer Disc

Consumer_Disc_Higher_Than_Eve_df=Combined_Sectors2_df.loc[Combined_Sectors2_df["Consumer Disc Close"]>= eve_price[3], :]
Consumer_Disc_Recovery_First_Row=Consumer_Disc_Higher_Than_Eve_df.iloc[0,:].tolist()
Consumer_Disc_Recovery_Date=Consumer_Disc_Recovery_First_Row[0]
recovery_dates.append(Consumer_Disc_Recovery_Date)

#Consumer Stap

Consumer_Stap_Higher_Than_Eve_df=Combined_Sectors2_df.loc[Combined_Sectors2_df["Consumer Stap Close"]>= eve_price[4], :]
Consumer_Stap_Recovery_First_Row=Consumer_Stap_Higher_Than_Eve_df.iloc[0,:].tolist()
Consumer_Stap_Recovery_Date=Consumer_Stap_Recovery_First_Row[0]
recovery_dates.append(Consumer_Stap_Recovery_Date)

# Health Care

Health_Care_Higher_Than_Eve_df=Combined_Sectors2_df.loc[Combined_Sectors2_df["Health Care Close"]>= eve_price[5], :]
Health_Care_Recovery_First_Row=Health_Care_Higher_Than_Eve_df.iloc[0,:].tolist()
Health_Care_Recovery_Date=Health_Care_Recovery_First_Row[0]
recovery_dates.append(Health_Care_Recovery_Date)

# Financial

Financial_Higher_Than_Eve_df=Combined_Sectors2_df.loc[Combined_Sectors2_df["Financial Close"]>= eve_price[6], :]
Financial_Recovery_First_Row=Financial_Higher_Than_Eve_df.iloc[0,:].tolist()
Financial_Recovery_Date=Financial_Recovery_First_Row[0]
recovery_dates.append(Financial_Recovery_Date)

# Technology

Technology_Higher_Than_Eve_df=Combined_Sectors2_df.loc[Combined_Sectors2_df["Technology Close"]>= eve_price[7], :]
Technology_Recovery_First_Row=Technology_Higher_Than_Eve_df.iloc[0,:].tolist()
Technology_Recovery_Date=Technology_Recovery_First_Row[0]
recovery_dates.append(Technology_Recovery_Date)

# Communications

Communications_Higher_Than_Eve_df=Combined_Sectors2_df.loc[Combined_Sectors2_df["Communications Close"]>= eve_price[8], :]
Communications_Recovery_First_Row=Communications_Higher_Than_Eve_df.iloc[0,:].tolist()
Communications_Recovery_Date=Communications_Recovery_First_Row[0]
recovery_dates.append(Communications_Recovery_Date)

# Utilities

Utilities_Higher_Than_Eve_df=Combined_Sectors2_df.loc[Combined_Sectors2_df["Utilities Close"]>= eve_price[9], :]
Utilities_Recovery_First_Row=Utilities_Higher_Than_Eve_df.iloc[0,:].tolist()
Utilities_Recovery_Date=Utilities_Recovery_First_Row[0]
recovery_dates.append(Utilities_Recovery_Date)

# Real Estate

Real_Estate_Higher_Than_Eve_df=Combined_Sectors2_df.loc[Combined_Sectors2_df["Real Estate Close"]>= eve_price[10], :]
Real_Estate_Recovery_First_Row=Real_Estate_Higher_Than_Eve_df.iloc[0,:].tolist()
Real_Estate_Recovery_Date=Real_Estate_Recovery_First_Row[0]
recovery_dates.append(Real_Estate_Recovery_Date)

# %%
# COVID 19 recession:
# Put the recovery dates in their own data frame.

Recovery_Dates_df=pd.DataFrame({"Date":recovery_dates, "Sector":sectors_title})


# Merge the recovery dates dataframe with the Eve-Sector data frame.

Eve_to_Recovery_df=pd.merge(Eve_Sector_df, Recovery_Dates_df, on='Sector')
Eve_to_Recovery_df=Eve_to_Recovery_df.rename(columns={"Date":"Recovery Date"})


# Format all of the dates so as to remove the time.

Eve_to_Recovery_df['Recession End'] = pd.to_datetime(Eve_to_Recovery_df['Recession End']).dt.date
Eve_to_Recovery_df['Recession Start'] = pd.to_datetime(Eve_to_Recovery_df['Recession Start']).dt.date
Eve_to_Recovery_df['Recovery Date'] = pd.to_datetime(Eve_to_Recovery_df['Recovery Date']).dt.date

# %%
# COVID 19 recession:
# Determine the number of days between Recession End and Recovery Date for each sector.

Days_To_Recover_df=Eve_to_Recovery_df['Recovery Date']-Eve_to_Recovery_df['Recession End']
Eve_to_Recovery_df["Days to Recover"]=Days_To_Recover_df


# Determine the number of days between Recession Start and Recession End for each sector.

Length_Of_Recession_df=Eve_to_Recovery_df['Recession End']-Eve_to_Recovery_df['Recession Start']
Eve_to_Recovery_df["Length of Recession"]=Length_Of_Recession_df


# Express the recovery time as a percentage of the recession length for each sector.

Percentage_df=Eve_to_Recovery_df['Days to Recover']/Eve_to_Recovery_df['Length of Recession']
Eve_to_Recovery_df["QRec"]=Percentage_df
Eve_to_Recovery_df
# Out:
#    Recession Start Recession End          Sector    Eve Price Recovery Date  \
# 0       2020-01-31    2020-04-01          Energy   405.450012    2021-05-17
# 1       2020-01-31    2020-04-01       Materials   361.989990    2020-06-03
# 2       2020-01-31    2020-04-01     Industrials   684.119995    2020-10-12
# 3       2020-01-31    2020-04-01   Consumer Disc   992.010010    2020-05-26
# 4       2020-01-31    2020-04-01   Consumer Stap   648.250000    2020-08-04
# 5       2020-01-31    2020-04-01     Health Care  1153.959961    2020-04-17
# 6       2020-01-31    2020-04-01       Financial   497.100006    2021-01-06
# 7       2020-01-31    2020-04-01      Technology  1673.910034    2020-05-11
# 8       2020-01-31    2020-04-01  Communications   182.839996    2020-06-02
# 9       2020-01-31    2020-04-01       Utilities   350.079987    2021-08-17
# 10      2020-01-31    2020-04-01     Real Estate   243.619995    2021-03-15
#
#    Days to Recover Length of Recession      QRec
# ...

# %%
# COVID 19 recession:
# Create bar chart.

sectors=Eve_to_Recovery_df["Sector"].tolist()
QRec = Eve_to_Recovery_df["QRec"].tolist()

x_axis=np.arange(len(QRec))
plt.bar(x_axis, QRec, color="b", align="center")

tick_locations=[value for value in x_axis]
plt.xticks(tick_locations, sectors, rotation='vertical')

plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(QRec)+0.5)

plt.title("Q-Rec score for each Sector after COVID recession.")
plt.xlabel("Sectors")
plt.ylabel("Q-Rec Score")

plt.savefig(f"QRec by Sector ({COVID_start.year}).png")

# %%
# COVID 19 recession:
# Establish paths for CSV import in next step.

Market = "COVID_Recession/^GSPC.csv"


# Create a data frame for the market using its CSV file.

Market_df = pd.read_csv(Market)


# Rename the column headers to avoid conflicts when merging data frames.

Market_Cleaned_df=Market_df.rename(columns={"Open":"Market Open", "High": "Market High", "Low": "Market Low", "Close":"Market Close", "Adj Close":"Adj Close Market", "Volume":"Market Volume"})

#Determine the Market price on the eve of the recession.

Market_Price_Eve = Market_Cleaned_df["Market Close"][0]
Market_eve_date=Market_Cleaned_df["Date"][0]
Market_Price_Eve
# Out:
# 3225.52001953125

# %%
# COVID 19 recession:
# Establish paths for CSV import in next step.

Market2 = "Post_COVID_Recession/^GSPC.csv"


# Create a data frame for the market using its CSV file.

Market2_df = pd.read_csv(Market2)


# Rename the column headers to avoid conflicts when merging data frames.

Market2_Cleaned_df=Market2_df.rename(columns={"Open":"Market Open", "High": "Market High", "Low": "Market Low", "Close":"Market Close", "Adj Close":"Adj Close Market", "Volume":"Market Volume"})

# %%
# COVID 19 recession:
# Establish an empty list to house the market's recovery date. 

market_recovery_date=[]


# Analyse the market's recovery.

Market_Higher_Than_Eve_df=Market2_Cleaned_df.loc[Market2_Cleaned_df["Market Close"]>= Market_Price_Eve, :]
Market_Recovery_First_Row=Market_Higher_Than_Eve_df.iloc[0,:].tolist()
Market_Recovery_Date=Market_Recovery_First_Row[0]
Market_Recovery_Date
# Out:
# '2020-06-08'

# %%
# COVID 19 recession:
# Determine the number of days between Recession End and Recovery Date for the market.

market_recovery_date=[]
for sector in sectors_title:
    market_recovery_date.append(Market_Recovery_Date)

    
# Put the recovery dates in their own data frame.

Market_Recovery_Date_df=pd.DataFrame({"Market Recovery Date":market_recovery_date, "Sector":sectors_title})


# Merge the market recovery dates dataframe with the Eve-Sector data frame.

Eve_to_Recovery_MARKET_df=pd.merge(Eve_to_Recovery_df, Market_Recovery_Date_df, on='Sector')


# Format all of the dates so as to remove the time.

Eve_to_Recovery_MARKET_df['Market Recovery Date'] = pd.to_datetime(Eve_to_Recovery_MARKET_df['Market Recovery Date']).dt.date


# Determine the number of days between Recession Start and Recovery Date for each sector.

Market_Days_To_Recover=Eve_to_Recovery_MARKET_df['Market Recovery Date']-Eve_to_Recovery_MARKET_df['Recession End']
Eve_to_Recovery_MARKET_df["Market Days to Recover"]=Market_Days_To_Recover


# Express the recovery time as a percentage of the recession length for the market.

Market_QRec_df=Eve_to_Recovery_MARKET_df['Market Days to Recover']/Eve_to_Recovery_MARKET_df['Length of Recession']
Eve_to_Recovery_MARKET_df["Market QRec"]=Market_QRec_df
Eve_to_Recovery_MARKET_df
# Out:
#    Recession Start Recession End          Sector    Eve Price Recovery Date  \
# 0       2020-01-31    2020-04-01          Energy   405.450012    2021-05-17
# 1       2020-01-31    2020-04-01       Materials   361.989990    2020-06-03
# 2       2020-01-31    2020-04-01     Industrials   684.119995    2020-10-12
# 3       2020-01-31    2020-04-01   Consumer Disc   992.010010    2020-05-26
# 4       2020-01-31    2020-04-01   Consumer Stap   648.250000    2020-08-04
# 5       2020-01-31    2020-04-01     Health Care  1153.959961    2020-04-17
# 6       2020-01-31    2020-04-01       Financial   497.100006    2021-01-06
# 7       2020-01-31    2020-04-01      Technology  1673.910034    2020-05-11
# 8       2020-01-31    2020-04-01  Communications   182.839996    2020-06-02
# 9       2020-01-31    2020-04-01       Utilities   350.079987    2021-08-17
# 10      2020-01-31    2020-04-01     Real Estate   243.619995    2021-03-15
#
# ...

# %%
# COVID 19 recession:
# Create bar chart for Sector QRec and Market QRec.

w=0.2
x=Eve_to_Recovery_MARKET_df["Sector"].tolist()

QRec = Eve_to_Recovery_MARKET_df["QRec"].tolist()
Market_QRec = Eve_to_Recovery_MARKET_df["Market QRec"].tolist()

bar1=np.arange(len(x))
bar2=[i+w for i in bar1]

plt.bar(bar1, QRec, w, label="sector")
plt.bar(bar2, Market_QRec, w, label="market")

plt.xticks(bar1, x, rotation='vertical')

plt.xlim(-0.75, len(x)-0.25)
plt.ylim(0, max(QRec)+0.5)

plt.title("QRec and Market QRec score - COVID recession.")
plt.xlabel("Sectors")
plt.ylabel("Q-Rec Score")

colors = {'Sector QRec':'royalblue', 'Market QRec':'orangered'}         
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
plt.legend(handles, labels)

plt.savefig(f"QRec and Market QRec by Sector ({COVID_start.year}).png")

# %%
# GFC recession:
# Examine GFC recession timeframe:

GFC_start = datetime(2007,12,1)
GFC_end = datetime(2009,6,1)

sector_list = ['^GSPC','^SP500-40','^SP500-25','^SP500-30',"^SP500-35","^SP500-20","^SP500-45","^SP500-15","^SP500-60","^SP500-50","^SP500-55","^GSPE"]
sector_name = ["S_P500", "Financials","Consumer_Discretionary","Consumer_Staples","Health","Industrials","Information_Tech","Materials","Real_Estate","Tele_Services","Utilities","Energy"]
thisyear = ['^GSPC','^SP500-40','^SP500-25','^SP500-30',"^SP500-35","^SP500-20","^SP500-45","^SP500-15","^SP500-60","^SP500-50","^SP500-55","^GSPE"]

# Extract data for each sector from Yahoo Finance and export it to its own CSV file.

for sector in sector_list: 
    file_name=str(sector)+".csv"
    thisyear[sector_list.index(sector)] = globals()[sector] = yf.download(sector, GFC_start, GFC_end)
    thisyear[sector_list.index(sector)].to_csv(f"GFC_Recession/{file_name}", index=True, header=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# GFC recession:
# Establish paths for CSV import in next step.

Energy = "GFC_Recession/^GSPE.csv"
Materials = "GFC_Recession/^SP500-15.csv"
Industrials = "GFC_Recession/^SP500-20.csv"
Consumer_Disc = "GFC_Recession/^SP500-25.csv"
Consumer_Stap = "GFC_Recession/^SP500-30.csv"
Health_Care = "GFC_Recession/^SP500-35.csv"
Financial = "GFC_Recession/^SP500-40.csv"
Technology = "GFC_Recession/^SP500-45.csv"
Communications = "GFC_Recession/^SP500-50.csv"
Utilities = "GFC_Recession/^SP500-55.csv"
Real_Estate = "GFC_Recession/^SP500-60.csv"


# Create a data frame for each sector using its CSV file.

Energy_df = pd.read_csv(Energy)
Materials_df = pd.read_csv(Materials)
Industrials_df = pd.read_csv(Industrials)
Consumer_Disc_df = pd.read_csv(Consumer_Disc)
Consumer_Stap_df = pd.read_csv(Consumer_Stap)
Health_Care_df = pd.read_csv(Health_Care)
Financial_df = pd.read_csv(Financial)
Technology_df = pd.read_csv(Technology)
Communications_df = pd.read_csv(Communications)
Utilities_df = pd.read_csv(Utilities)
Real_Estate_df = pd.read_csv(Real_Estate)


# Rename the column headers to avoid conflicts when merging data frames.

Energy_Cleaned_df=Energy_df.rename(columns={"Open":"Energy Open", "High": "Energy High", "Low": "Energy Low", "Close":"Energy Close", "Adj Close":"Adj Close Energy", "Volume":"Energy Volume"})
Materials_Cleaned_df=Materials_df.rename(columns={"Open":"Materials Open", "High": "Materials High", "Low": "Materials Low", "Close":"Materials Close", "Adj Close":"Adj Close Materials", "Volume":"Materials Volume"})
Industrials_Cleaned_df=Industrials_df.rename(columns={"Open":"Industrials Open", "High": "Industrials High", "Low": "Industrials Low", "Close":"Industrials Close", "Adj Close":"Adj Close Industrials", "Volume":"Industrials Volume"})
Consumer_Disc_Cleaned_df=Consumer_Disc_df.rename(columns={"Open":"Consumer Disc Open", "High": "Consumer Disc High", "Low": "Consumer Disc Low", "Close":"Consumer Disc Close", "Adj Close":"Adj Close Consumer Disc", "Volume":"Consumer Disc Volume"})
Consumer_Stap_Cleaned_df=Consumer_Stap_df.rename(columns={"Open":"Consumer Stap Open", "High": "Consumer Stap High", "Low": "Consumer Stap Low", "Close":"Consumer Stap Close", "Adj Close":"Adj Close Consumer Stap", "Volume":"Consumer Stap Volume"})
Health_Care_Cleaned_df=Health_Care_df.rename(columns={"Open":"Health Care Open", "High": "Health Care High", "Low": "Health Care Low", "Close":"Health Care Close", "Adj Close":"Adj Close Health Care", "Volume":"Health Care Volume"})
Financial_Cleaned_df=Financial_df.rename(columns={"Open":"Financial Open", "High": "Financial High", "Low": "Financial Low", "Close":"Financial Close", "Adj Close":"Adj Close Financial", "Volume":"Financial Volume"})
Technology_Cleaned_df=Technology_df.rename(columns={"Open":"Technology Open", "High": "Technology High", "Low": "Technology Low", "Close":"Technology Close", "Adj Close":"Adj Close Technology", "Volume":"Technology Volume"})
Communications_Cleaned_df=Communications_df.rename(columns={"Open":"Communications Open", "High": "Communications High", "Low": "Communications Low", "Close":"Communications Close", "Adj Close":"Adj Close Communications", "Volume":"Communications Volume"})
Utilities_Cleaned_df=Utilities_df.rename(columns={"Open":"Utilities Open", "High": "Utilities High", "Low": "Utilities Low", "Close":"Utilities Close", "Adj Close":"Adj Close Utilities", "Volume":"Utilities Volume"})
Real_Estate_Cleaned_df=Real_Estate_df.rename(columns={"Open":"Real Estate Open", "High": "Real Estate High", "Low": "Real Estate Low", "Close":"Real Estate Close", "Adj Close":"Adj Close Real Estate", "Volume":"Real Estate Volume"})


# Merge all sector data frames together using the DATE as the merge parameter.

combined1_df = pd.merge(Energy_Cleaned_df, Materials_Cleaned_df, how="left", on=["Date", "Date"])
combined2_df = pd.merge(combined1_df, Industrials_Cleaned_df, how="left", on=["Date", "Date"])
combined3_df = pd.merge(combined2_df, Consumer_Disc_Cleaned_df, how="left", on=["Date", "Date"])
combined4_df = pd.merge(combined3_df, Consumer_Stap_Cleaned_df, how="left", on=["Date", "Date"])
combined5_df = pd.merge(combined4_df, Health_Care_Cleaned_df, how="left", on=["Date", "Date"])
combined6_df = pd.merge(combined5_df, Financial_Cleaned_df, how="left", on=["Date", "Date"])
combined7_df = pd.merge(combined6_df, Technology_Cleaned_df, how="left", on=["Date", "Date"])
combined8_df = pd.merge(combined7_df, Communications_Cleaned_df, how="left", on=["Date", "Date"])
combined9_df = pd.merge(combined8_df, Utilities_Cleaned_df, how="left", on=["Date", "Date"])
Combined_Sectors3_df = pd.merge(combined9_df, Real_Estate_Cleaned_df, how="left", on=["Date", "Date"])
Combined_Sectors3_df[["Date", "Energy Close", "Materials Close", "Industrials Close", "Consumer Disc Close", "Consumer Stap Close", "Health Care Close", "Financial Close", "Technology Close", "Communications Close", "Utilities Close", "Real Estate Close"]].head()
# Out:
#          Date  Energy Close  Materials Close  Industrials Close  \
# 0  2007-11-30    562.130005       257.589996         357.470001
# 1  2007-12-03    563.830017       256.570007         353.540009
# 2  2007-12-04    558.919983       254.850006         351.420013
# 3  2007-12-05    569.239990       259.269989         356.630005
# 4  2007-12-06    583.150024       264.359985         362.390015
#
#    Consumer Disc Close  Consumer Stap Close  Health Care Close  \
# 0           273.029999           303.329987         422.809998
# 1           271.980011           302.019989         420.109985
# 2           270.899994           301.709991         418.839996
# 3           270.160004           303.510010         423.929993
# 4           273.130005           305.540009         426.059998
#
#    Financial Close  Technology Close  Communications Close  Utilities Close  \
# 0       415.890015        405.640015            163.229996       216.029999
# ...

# %%
# Create graphs showing the performance of each sector during the GFC recession.

plt.figure(figsize=(15, 40))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, sector in enumerate(sector_list, 1):
    plt.subplot(11, 2, i)
    thisyear[i-1]['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {sector_name[i - 1]}")
plt.tight_layout()
plt.savefig(f"Adj Close Change by Sectors({COVID_start.year}).png")

# %%
# GFC recession:
# Create an empty list to house the closing price for each sector, the list of sector names and the date on the eve of the recession.

eve_price=[]
sectors_title=["Energy", "Materials", "Industrials", "Consumer Disc", "Consumer Stap", "Health Care", "Financial", "Technology", "Communications", "Utilities", "Real Estate"]
eve_date_list=[]
end_date_list=[]

# %%
# GFC recession:
# Extract the closing price for each sector on the eve of the recession and its corresponding date.

for sector in sectors_title:
    try:
        Price_Start = Combined_Sectors3_df[f"{sector} Close"][0]
        eve_price.append(Price_Start)
        eve_date=Combined_Sectors3_df["Date"][0]
        eve_date_list.append(eve_date)
        end_date_list.append(GFC_end)
    except KeyError:
        eve_price.append("No Data")
        
# Create a dataframe for Recession Start Dates, End Dates, Sector and Sector Price (eve of recession).

Eve_Sector_df=pd.DataFrame({"Recession Start":eve_date_list, "Recession End":end_date_list, "Sector":sectors_title, "Eve Price":eve_price})
Eve_Sector_df
# Out:
#    Recession Start Recession End          Sector   Eve Price
# 0       2007-11-30    2009-06-01          Energy  562.130005
# 1       2007-11-30    2009-06-01       Materials  257.589996
# 2       2007-11-30    2009-06-01     Industrials  357.470001
# 3       2007-11-30    2009-06-01   Consumer Disc  273.029999
# 4       2007-11-30    2009-06-01   Consumer Stap  303.329987
# 5       2007-11-30    2009-06-01     Health Care  422.809998
# 6       2007-11-30    2009-06-01       Financial  415.890015
# 7       2007-11-30    2009-06-01      Technology  405.640015
# 8       2007-11-30    2009-06-01  Communications  163.229996
# 9       2007-11-30    2009-06-01       Utilities  216.029999
# 10      2007-11-30    2009-06-01     Real Estate  151.550003

# %%
# GFC recession:
# Examine all of the POST GFC recession data:

GFC_end = datetime(2009,6,1)
Today_Date = datetime(2022,3,22)

sector_list = ['^GSPC','^SP500-40','^SP500-25','^SP500-30',"^SP500-35","^SP500-20","^SP500-45","^SP500-15","^SP500-60","^SP500-50","^SP500-55","^GSPE"]
sector_name = ["S_P500", "Financials","Consumer_Discretionary","Consumer_Staples","Health","Industrials","Information_Tech","Materials","Real_Estate","Tele_Services","Utilities","Energy"]
thisyear = ['^GSPC','^SP500-40','^SP500-25','^SP500-30',"^SP500-35","^SP500-20","^SP500-45","^SP500-15","^SP500-60","^SP500-50","^SP500-55","^GSPE"]

# Extract data for each sector from Yahoo Finance and export it to its own CSV file.

for sector in sector_list: 
    file_name=str(sector)+".csv"
    thisyear[sector_list.index(sector)] = globals()[sector] = yf.download(sector, GFC_end, Today_Date)
    thisyear[sector_list.index(sector)].to_csv(f"Post_GFC_Recession/{file_name}", index=True, header=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# GFC recession:
# Establish paths for CSV import in next step.

Energy2 = "Post_GFC_Recession/^GSPE.csv"
Materials2 = "Post_GFC_Recession/^SP500-15.csv"
Industrials2 = "Post_GFC_Recession/^SP500-20.csv"
Consumer_Disc2 = "Post_GFC_Recession/^SP500-25.csv"
Consumer_Stap2 = "Post_GFC_Recession/^SP500-30.csv"
Health_Care2 = "Post_GFC_Recession/^SP500-35.csv"
Financial2 = "Post_GFC_Recession/^SP500-40.csv"
Technology2 = "Post_GFC_Recession/^SP500-45.csv"
Communications2 = "Post_GFC_Recession/^SP500-50.csv"
Utilities2 = "Post_GFC_Recession/^SP500-55.csv"
Real_Estate2 = "Post_GFC_Recession/^SP500-60.csv"


# Create a data frame for each sector using its CSV file.

Energy2_df = pd.read_csv(Energy2)
Materials2_df = pd.read_csv(Materials2)
Industrials2_df = pd.read_csv(Industrials2)
Consumer_Disc2_df = pd.read_csv(Consumer_Disc2)
Consumer_Stap2_df = pd.read_csv(Consumer_Stap2)
Health_Care2_df = pd.read_csv(Health_Care2)
Financial2_df = pd.read_csv(Financial2)
Technology2_df = pd.read_csv(Technology2)
Communications2_df = pd.read_csv(Communications2)
Utilities2_df = pd.read_csv(Utilities2)
Real_Estate2_df = pd.read_csv(Real_Estate2)


# Rename the column headers to avoid conflicts when merging data frames.

Energy2_Cleaned_df=Energy2_df.rename(columns={"Open":"Energy Open", "High": "Energy High", "Low": "Energy Low", "Close":"Energy Close", "Adj Close":"Adj Close Energy", "Volume":"Energy Volume"})
Materials2_Cleaned_df=Materials2_df.rename(columns={"Open":"Materials Open", "High": "Materials High", "Low": "Materials Low", "Close":"Materials Close", "Adj Close":"Adj Close Materials", "Volume":"Materials Volume"})
Industrials2_Cleaned_df=Industrials2_df.rename(columns={"Open":"Industrials Open", "High": "Industrials High", "Low": "Industrials Low", "Close":"Industrials Close", "Adj Close":"Adj Close Industrials", "Volume":"Industrials Volume"})
Consumer_Disc2_Cleaned_df=Consumer_Disc2_df.rename(columns={"Open":"Consumer Disc Open", "High": "Consumer Disc High", "Low": "Consumer Disc Low", "Close":"Consumer Disc Close", "Adj Close":"Adj Close Consumer Disc", "Volume":"Consumer Disc Volume"})
Consumer_Stap2_Cleaned_df=Consumer_Stap2_df.rename(columns={"Open":"Consumer Stap Open", "High": "Consumer Stap High", "Low": "Consumer Stap Low", "Close":"Consumer Stap Close", "Adj Close":"Adj Close Consumer Stap", "Volume":"Consumer Stap Volume"})
Health_Care2_Cleaned_df=Health_Care2_df.rename(columns={"Open":"Health Care Open", "High": "Health Care High", "Low": "Health Care Low", "Close":"Health Care Close", "Adj Close":"Adj Close Health Care", "Volume":"Health Care Volume"})
Financial2_Cleaned_df=Financial2_df.rename(columns={"Open":"Financial Open", "High": "Financial High", "Low": "Financial Low", "Close":"Financial Close", "Adj Close":"Adj Close Financial", "Volume":"Financial Volume"})
Technology2_Cleaned_df=Technology2_df.rename(columns={"Open":"Technology Open", "High": "Technology High", "Low": "Technology Low", "Close":"Technology Close", "Adj Close":"Adj Close Technology", "Volume":"Technology Volume"})
Communications2_Cleaned_df=Communications2_df.rename(columns={"Open":"Communications Open", "High": "Communications High", "Low": "Communications Low", "Close":"Communications Close", "Adj Close":"Adj Close Communications", "Volume":"Communications Volume"})
Utilities2_Cleaned_df=Utilities2_df.rename(columns={"Open":"Utilities Open", "High": "Utilities High", "Low": "Utilities Low", "Close":"Utilities Close", "Adj Close":"Adj Close Utilities", "Volume":"Utilities Volume"})
Real_Estate2_Cleaned_df=Real_Estate2_df.rename(columns={"Open":"Real Estate Open", "High": "Real Estate High", "Low": "Real Estate Low", "Close":"Real Estate Close", "Adj Close":"Adj Close Real Estate", "Volume":"Real Estate Volume"})


# Merge all sector data frames together using the DATE as the merge parameter.

combined1_df = pd.merge(Energy2_Cleaned_df, Materials2_Cleaned_df, how="left", on=["Date", "Date"])
combined2_df = pd.merge(combined1_df, Industrials2_Cleaned_df, how="left", on=["Date", "Date"])
combined3_df = pd.merge(combined2_df, Consumer_Disc2_Cleaned_df, how="left", on=["Date", "Date"])
combined4_df = pd.merge(combined3_df, Consumer_Stap2_Cleaned_df, how="left", on=["Date", "Date"])
combined5_df = pd.merge(combined4_df, Health_Care2_Cleaned_df, how="left", on=["Date", "Date"])
combined6_df = pd.merge(combined5_df, Financial2_Cleaned_df, how="left", on=["Date", "Date"])
combined7_df = pd.merge(combined6_df, Technology2_Cleaned_df, how="left", on=["Date", "Date"])
combined8_df = pd.merge(combined7_df, Communications2_Cleaned_df, how="left", on=["Date", "Date"])
combined9_df = pd.merge(combined8_df, Utilities2_Cleaned_df, how="left", on=["Date", "Date"])
Combined_Sectors4_df = pd.merge(combined9_df, Real_Estate2_Cleaned_df, how="left", on=["Date", "Date"])
Combined_Sectors4_df[["Date", "Energy Close", "Materials Close", "Industrials Close", "Consumer Disc Close", "Consumer Stap Close", "Health Care Close", "Financial Close", "Technology Close", "Communications Close", "Utilities Close", "Real Estate Close"]].head()
# Out:
#          Date  Energy Close  Materials Close  Industrials Close  \
# 0  2009-06-01    407.519989       167.330002         205.009995
# 1  2009-06-02    407.690002       169.550003         205.889999
# 2  2009-06-03    394.070007       163.559998         201.820007
# 3  2009-06-04    401.980011       167.179993         205.429993
# 4  2009-06-05    398.250000       164.449997         206.550003
#
#    Consumer Disc Close  Consumer Stap Close  Health Care Close  \
# 0           189.949997           242.729996         300.190002
# 1           191.679993           245.389999         303.440002
# 2           189.779999           244.000000         302.100006
# 3           189.270004           244.229996         298.359985
# 4           188.039993           242.720001         296.420013
#
#    Financial Close  Technology Close  Communications Close  Utilities Close  \
# 0       165.309998        285.640015            102.769997       139.500000
# ...

# %%
# Create graphs showing the post GFC recession performance of each sector.

plt.figure(figsize=(15, 40))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, sector in enumerate(sector_list, 1):
    plt.subplot(11, 2, i)
    thisyear[i-1]['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {sector_name[i - 1]}")
plt.tight_layout()
plt.savefig(f"Adj Close Change by Sectors({COVID_start.year}).png")

# %%
# GFC recession:
# Establish an empty list to house each sector's recovery date. 

recovery_dates=[]

# Analyse each sector's recovery.

# Energy:

Energy_Higher_Than_Eve_df=Combined_Sectors4_df.loc[Combined_Sectors4_df["Energy Close"]>= eve_price[0], :]
Energy_Recovery_First_Row=Energy_Higher_Than_Eve_df.iloc[0,:].tolist()
Energy_Recovery_Date=Energy_Recovery_First_Row[0]
recovery_dates.append(Energy_Recovery_Date)

# Materials

Materials_Higher_Than_Eve_df=Combined_Sectors4_df.loc[Combined_Sectors4_df["Materials Close"]>= eve_price[1], :]
Materials_Recovery_First_Row=Materials_Higher_Than_Eve_df.iloc[0,:].tolist()
Materials_Recovery_Date=Materials_Recovery_First_Row[0]
recovery_dates.append(Materials_Recovery_Date)

#Industrials

Industrials_Higher_Than_Eve_df=Combined_Sectors4_df.loc[Combined_Sectors4_df["Industrials Close"]>= eve_price[2], :]
Industrials_Recovery_First_Row=Industrials_Higher_Than_Eve_df.iloc[0,:].tolist()
Industrials_Recovery_Date=Industrials_Recovery_First_Row[0]
recovery_dates.append(Industrials_Recovery_Date)

#Consumer Disc

Consumer_Disc_Higher_Than_Eve_df=Combined_Sectors4_df.loc[Combined_Sectors4_df["Consumer Disc Close"]>= eve_price[3], :]
Consumer_Disc_Recovery_First_Row=Consumer_Disc_Higher_Than_Eve_df.iloc[0,:].tolist()
Consumer_Disc_Recovery_Date=Consumer_Disc_Recovery_First_Row[0]
recovery_dates.append(Consumer_Disc_Recovery_Date)

#Consumer Stap

Consumer_Stap_Higher_Than_Eve_df=Combined_Sectors4_df.loc[Combined_Sectors4_df["Consumer Stap Close"]>= eve_price[4], :]
Consumer_Stap_Recovery_First_Row=Consumer_Stap_Higher_Than_Eve_df.iloc[0,:].tolist()
Consumer_Stap_Recovery_Date=Consumer_Stap_Recovery_First_Row[0]
recovery_dates.append(Consumer_Stap_Recovery_Date)

# Health Care

Health_Care_Higher_Than_Eve_df=Combined_Sectors4_df.loc[Combined_Sectors4_df["Health Care Close"]>= eve_price[5], :]
Health_Care_Recovery_First_Row=Health_Care_Higher_Than_Eve_df.iloc[0,:].tolist()
Health_Care_Recovery_Date=Health_Care_Recovery_First_Row[0]
recovery_dates.append(Health_Care_Recovery_Date)

# Financial

Financial_Higher_Than_Eve_df=Combined_Sectors4_df.loc[Combined_Sectors4_df["Financial Close"]>= eve_price[6], :]
Financial_Recovery_First_Row=Financial_Higher_Than_Eve_df.iloc[0,:].tolist()
Financial_Recovery_Date=Financial_Recovery_First_Row[0]
recovery_dates.append(Financial_Recovery_Date)

# Technology

Technology_Higher_Than_Eve_df=Combined_Sectors4_df.loc[Combined_Sectors4_df["Technology Close"]>= eve_price[7], :]
Technology_Recovery_First_Row=Technology_Higher_Than_Eve_df.iloc[0,:].tolist()
Technology_Recovery_Date=Technology_Recovery_First_Row[0]
recovery_dates.append(Technology_Recovery_Date)

# Communications

Communications_Higher_Than_Eve_df=Combined_Sectors4_df.loc[Combined_Sectors4_df["Communications Close"]>= eve_price[8], :]
Communications_Recovery_First_Row=Communications_Higher_Than_Eve_df.iloc[0,:].tolist()
Communications_Recovery_Date=Communications_Recovery_First_Row[0]
recovery_dates.append(Communications_Recovery_Date)

# Utilities

Utilities_Higher_Than_Eve_df=Combined_Sectors4_df.loc[Combined_Sectors4_df["Utilities Close"]>= eve_price[9], :]
Utilities_Recovery_First_Row=Utilities_Higher_Than_Eve_df.iloc[0,:].tolist()
Utilities_Recovery_Date=Utilities_Recovery_First_Row[0]
recovery_dates.append(Utilities_Recovery_Date)

# Real Estate

Real_Estate_Higher_Than_Eve_df=Combined_Sectors4_df.loc[Combined_Sectors4_df["Real Estate Close"]>= eve_price[10], :]
Real_Estate_Recovery_First_Row=Real_Estate_Higher_Than_Eve_df.iloc[0,:].tolist()
Real_Estate_Recovery_Date=Real_Estate_Recovery_First_Row[0]
recovery_dates.append(Real_Estate_Recovery_Date)

# %%
# GFC recession:
# Put the recovery dates in their own data frame.

Recovery_Dates_df=pd.DataFrame({"Date":recovery_dates, "Sector":sectors_title})


# Merge the recovery dates dataframe with the Eve-Sector data frame.

Eve_to_Recovery_df=pd.merge(Eve_Sector_df, Recovery_Dates_df, on='Sector')
Eve_to_Recovery_df=Eve_to_Recovery_df.rename(columns={"Date":"Recovery Date"})


# Format all of the dates so as to remove the time.

Eve_to_Recovery_df['Recession End'] = pd.to_datetime(Eve_to_Recovery_df['Recession End']).dt.date
Eve_to_Recovery_df['Recession Start'] = pd.to_datetime(Eve_to_Recovery_df['Recession Start']).dt.date
Eve_to_Recovery_df['Recovery Date'] = pd.to_datetime(Eve_to_Recovery_df['Recovery Date']).dt.date

# %%
# GFC recession:
# Determine the number of days between Recession End and Recovery Date for each sector.

Days_To_Recover_df=Eve_to_Recovery_df['Recovery Date']-Eve_to_Recovery_df['Recession End']
Eve_to_Recovery_df["Days to Recover"]=Days_To_Recover_df


# Determine the number of days between Recession Start and Recession End for each sector.

Length_Of_Recession_df=Eve_to_Recovery_df['Recession End']-Eve_to_Recovery_df['Recession Start']
Eve_to_Recovery_df["Length of Recession"]=Length_Of_Recession_df


# Express the recovery time as a percentage of the recession length for each sector.

Percentage_df=Eve_to_Recovery_df['Days to Recover']/Eve_to_Recovery_df['Length of Recession']
Eve_to_Recovery_df["QRec"]=Percentage_df
Eve_to_Recovery_df
# Out:
#    Recession Start Recession End          Sector   Eve Price Recovery Date  \
# 0       2007-11-30    2009-06-01          Energy  562.130005    2011-02-14
# 1       2007-11-30    2009-06-01       Materials  257.589996    2013-05-17
# 2       2007-11-30    2009-06-01     Industrials  357.470001    2013-02-19
# 3       2007-11-30    2009-06-01   Consumer Disc  273.029999    2010-04-14
# 4       2007-11-30    2009-06-01   Consumer Stap  303.329987    2010-12-16
# 5       2007-11-30    2009-06-01     Health Care  422.809998    2012-03-13
# 6       2007-11-30    2009-06-01       Financial  415.890015    2017-03-01
# 7       2007-11-30    2009-06-01      Technology  405.640015    2010-12-13
# 8       2007-11-30    2009-06-01  Communications  163.229996    2013-04-10
# 9       2007-11-30    2009-06-01       Utilities  216.029999    2014-04-15
# 10      2007-11-30    2009-06-01     Real Estate  151.550003    2012-07-17
#
#    Days to Recover Length of Recession      QRec
# ...

# %%
# GFC recession:
# Create bar chart.

sectors=Eve_to_Recovery_df["Sector"].tolist()
QRec = Eve_to_Recovery_df["QRec"].tolist()

x_axis=np.arange(len(QRec))
plt.bar(x_axis, QRec, color="b", align="center")

tick_locations=[value for value in x_axis]
plt.xticks(tick_locations, sectors, rotation='vertical')

plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(QRec)+0.5)

plt.title("Q-Rec score for each Sector after GFC recession.")
plt.xlabel("Sectors")
plt.ylabel("Q-Rec Score")

plt.savefig(f"QRec by Sector ({GFC_start.year}).png")

# %%
# GFC recession:
# Establish paths for CSV import in next step.

Market = "GFC_Recession/^GSPC.csv"


# Create a data frame for the market using its CSV file.

Market_df = pd.read_csv(Market)


# Rename the column headers to avoid conflicts when merging data frames.

Market_Cleaned_df=Market_df.rename(columns={"Open":"Market Open", "High": "Market High", "Low": "Market Low", "Close":"Market Close", "Adj Close":"Adj Close Market", "Volume":"Market Volume"})

#Determine the Market price on the eve of the recession.

Market_Price_Eve = Market_Cleaned_df["Market Close"][0]
Market_eve_date=Market_Cleaned_df["Date"][0]
Market_Price_Eve
# Out:
# 1481.1400146484375

# %%
# GFC recession:
# Establish paths for CSV import in next step.

Market2 = "Post_GFC_Recession/^GSPC.csv"


# Create a data frame for the market using its CSV file.

Market2_df = pd.read_csv(Market2)


# Rename the column headers to avoid conflicts when merging data frames.

Market2_Cleaned_df=Market2_df.rename(columns={"Open":"Market Open", "High": "Market High", "Low": "Market Low", "Close":"Market Close", "Adj Close":"Adj Close Market", "Volume":"Market Volume"})

# %%
# GFC recession:
# Establish an empty list to house the market's recovery date. 

market_recovery_date=[]


# Analyse the market's recovery.

Market_Higher_Than_Eve_df=Market2_Cleaned_df.loc[Market2_Cleaned_df["Market Close"]>= Market_Price_Eve, :]
Market_Recovery_First_Row=Market_Higher_Than_Eve_df.iloc[0,:].tolist()
Market_Recovery_Date=Market_Recovery_First_Row[0]
Market_Recovery_Date
# Out:
# '2013-01-18'

# %%
# GFC recession:
# Determine the number of days between Recession End and Recovery Date for the market.

market_recovery_date=[]
for sector in sectors_title:
    market_recovery_date.append(Market_Recovery_Date)

    
# Put the recovery dates in their own data frame.

Market_Recovery_Date_df=pd.DataFrame({"Market Recovery Date":market_recovery_date, "Sector":sectors_title})


# Merge the market recovery dates dataframe with the Eve-Sector data frame.

Eve_to_Recovery_MARKET1_df=pd.merge(Eve_to_Recovery_df, Market_Recovery_Date_df, on='Sector')


# Format all of the dates so as to remove the time.

Eve_to_Recovery_MARKET1_df['Market Recovery Date'] = pd.to_datetime(Eve_to_Recovery_MARKET1_df['Market Recovery Date']).dt.date


# Determine the number of days between Recession Start and Recovery Date for each sector.

Market_Days_To_Recover=Eve_to_Recovery_MARKET1_df['Market Recovery Date']-Eve_to_Recovery_MARKET1_df['Recession End']
Eve_to_Recovery_MARKET1_df["Market Days to Recover"]=Market_Days_To_Recover


# Express the recovery time as a percentage of the recession length for the market.

Market_QRec_df=Eve_to_Recovery_MARKET1_df['Market Days to Recover']/Eve_to_Recovery_MARKET1_df['Length of Recession']
Eve_to_Recovery_MARKET1_df["Market QRec"]=Market_QRec_df
Eve_to_Recovery_MARKET1_df
# Out:
#    Recession Start Recession End          Sector   Eve Price Recovery Date  \
# 0       2007-11-30    2009-06-01          Energy  562.130005    2011-02-14
# 1       2007-11-30    2009-06-01       Materials  257.589996    2013-05-17
# 2       2007-11-30    2009-06-01     Industrials  357.470001    2013-02-19
# 3       2007-11-30    2009-06-01   Consumer Disc  273.029999    2010-04-14
# 4       2007-11-30    2009-06-01   Consumer Stap  303.329987    2010-12-16
# 5       2007-11-30    2009-06-01     Health Care  422.809998    2012-03-13
# 6       2007-11-30    2009-06-01       Financial  415.890015    2017-03-01
# 7       2007-11-30    2009-06-01      Technology  405.640015    2010-12-13
# 8       2007-11-30    2009-06-01  Communications  163.229996    2013-04-10
# 9       2007-11-30    2009-06-01       Utilities  216.029999    2014-04-15
# 10      2007-11-30    2009-06-01     Real Estate  151.550003    2012-07-17
#
# ...

# %%
# GFC recession:
# Create bar chart for Sector QRec and Market QRec.

w=0.2
x=Eve_to_Recovery_MARKET1_df["Sector"].tolist()

QRec = Eve_to_Recovery_MARKET1_df["QRec"].tolist()
Market_QRec = Eve_to_Recovery_MARKET1_df["Market QRec"].tolist()

bar1=np.arange(len(x))
bar2=[i+w for i in bar1]

plt.bar(bar1, QRec, w, label="sector")
plt.bar(bar2, Market_QRec, w, label="market")

plt.xticks(bar1, x, rotation='vertical')

plt.xlim(-0.75, len(x)-0.25)
plt.ylim(0, max(QRec)+0.5)

plt.title("QRec and Market QRec score - GFC recession.")
plt.xlabel("Sectors")
plt.ylabel("Q-Rec Score")

colors = {'Sector QRec':'royalblue', 'Market QRec':'orangered'}         
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
plt.legend(handles, labels)

plt.savefig(f"QRec and Market QRec by Sector ({GFC_start.year}).png")

# %%
# GFC recession:
# Create bar chart for Sector QRec and Market QRec.

w=0.2
x=Eve_to_Recovery_MARKET1_df["Sector"].tolist()

QRecGFC = Eve_to_Recovery_MARKET1_df["QRec"].tolist()
QRecCOVID = Eve_to_Recovery_MARKET_df["QRec"].tolist()

bar1=np.arange(len(x))
bar2=[i+w for i in bar1]

plt.bar(bar1, QRecGFC, w, label="GFC")
plt.bar(bar2, QRecCOVID, w, label="COVID")

plt.xticks(bar1, x, rotation='vertical')

plt.xlim(-0.75, len(x)-0.25)
plt.ylim(0, max(QRec)+5.5)

plt.title("QRec from GFC and COVID.")
plt.xlabel("Sectors")
plt.ylabel("Q-Rec Score")

colors = {'GFC QRec':'royalblue', 'COVID QRec':'orangered'}         
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
plt.legend(handles, labels)

plt.savefig(f"QRec for GFC and COVID by Sector.png")

# %%
# Dot-Com recession:
# Examine GFC recession timeframe:

Dot_Com_start = datetime(2001,3,1)
Dot_Com_end = datetime(2001,11,1)

sector_list = ['^GSPC','^SP500-40','^SP500-25','^SP500-30',"^SP500-35","^SP500-20","^SP500-45","^SP500-15","^SP500-50","^SP500-55","^GSPE"]
sector_name = ["S_P500", "Financials","Consumer_Discretionary","Consumer_Staples","Health","Industrials","Information_Tech","Materials","Tele_Services","Utilities","Energy"]
thisyear = ['^GSPC','^SP500-40','^SP500-25','^SP500-30',"^SP500-35","^SP500-20","^SP500-45","^SP500-15","^SP500-50","^SP500-55","^GSPE"]

# Extract data for each sector from Yahoo Finance and export it to its own CSV file.

for sector in sector_list: 
    file_name=str(sector)+".csv"
    thisyear[sector_list.index(sector)] = globals()[sector] = yf.download(sector, Dot_Com_start, Dot_Com_end)
    thisyear[sector_list.index(sector)].to_csv(f"Dot_Com_Recession/{file_name}", index=True, header=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Dot-Com recession:
# Establish paths for CSV import in next step.

Energy = "Dot_Com_Recession/^GSPE.csv"
Materials = "Dot_Com_Recession/^SP500-15.csv"
Industrials = "Dot_Com_Recession/^SP500-20.csv"
Consumer_Disc = "Dot_Com_Recession/^SP500-25.csv"
Consumer_Stap = "Dot_Com_Recession/^SP500-30.csv"
Health_Care = "Dot_Com_Recession/^SP500-35.csv"
Financial = "Dot_Com_Recession/^SP500-40.csv"
Technology = "Dot_Com_Recession/^SP500-45.csv"
Communications = "Dot_Com_Recession/^SP500-50.csv"
Utilities = "Dot_Com_Recession/^SP500-55.csv"


# Create a data frame for each sector using its CSV file.

Energy_df = pd.read_csv(Energy)
Materials_df = pd.read_csv(Materials)
Industrials_df = pd.read_csv(Industrials)
Consumer_Disc_df = pd.read_csv(Consumer_Disc)
Consumer_Stap_df = pd.read_csv(Consumer_Stap)
Health_Care_df = pd.read_csv(Health_Care)
Financial_df = pd.read_csv(Financial)
Technology_df = pd.read_csv(Technology)
Communications_df = pd.read_csv(Communications)
Utilities_df = pd.read_csv(Utilities)


# Rename the column headers to avoid conflicts when merging data frames.

Energy_Cleaned_df=Energy_df.rename(columns={"Open":"Energy Open", "High": "Energy High", "Low": "Energy Low", "Close":"Energy Close", "Adj Close":"Adj Close Energy", "Volume":"Energy Volume"})
Materials_Cleaned_df=Materials_df.rename(columns={"Open":"Materials Open", "High": "Materials High", "Low": "Materials Low", "Close":"Materials Close", "Adj Close":"Adj Close Materials", "Volume":"Materials Volume"})
Industrials_Cleaned_df=Industrials_df.rename(columns={"Open":"Industrials Open", "High": "Industrials High", "Low": "Industrials Low", "Close":"Industrials Close", "Adj Close":"Adj Close Industrials", "Volume":"Industrials Volume"})
Consumer_Disc_Cleaned_df=Consumer_Disc_df.rename(columns={"Open":"Consumer Disc Open", "High": "Consumer Disc High", "Low": "Consumer Disc Low", "Close":"Consumer Disc Close", "Adj Close":"Adj Close Consumer Disc", "Volume":"Consumer Disc Volume"})
Consumer_Stap_Cleaned_df=Consumer_Stap_df.rename(columns={"Open":"Consumer Stap Open", "High": "Consumer Stap High", "Low": "Consumer Stap Low", "Close":"Consumer Stap Close", "Adj Close":"Adj Close Consumer Stap", "Volume":"Consumer Stap Volume"})
Health_Care_Cleaned_df=Health_Care_df.rename(columns={"Open":"Health Care Open", "High": "Health Care High", "Low": "Health Care Low", "Close":"Health Care Close", "Adj Close":"Adj Close Health Care", "Volume":"Health Care Volume"})
Financial_Cleaned_df=Financial_df.rename(columns={"Open":"Financial Open", "High": "Financial High", "Low": "Financial Low", "Close":"Financial Close", "Adj Close":"Adj Close Financial", "Volume":"Financial Volume"})
Technology_Cleaned_df=Technology_df.rename(columns={"Open":"Technology Open", "High": "Technology High", "Low": "Technology Low", "Close":"Technology Close", "Adj Close":"Adj Close Technology", "Volume":"Technology Volume"})
Communications_Cleaned_df=Communications_df.rename(columns={"Open":"Communications Open", "High": "Communications High", "Low": "Communications Low", "Close":"Communications Close", "Adj Close":"Adj Close Communications", "Volume":"Communications Volume"})
Utilities_Cleaned_df=Utilities_df.rename(columns={"Open":"Utilities Open", "High": "Utilities High", "Low": "Utilities Low", "Close":"Utilities Close", "Adj Close":"Adj Close Utilities", "Volume":"Utilities Volume"})


# Merge all sector data frames together using the DATE as the merge parameter.

combined1_df = pd.merge(Energy_Cleaned_df, Materials_Cleaned_df, how="left", on=["Date", "Date"])
combined2_df = pd.merge(combined1_df, Industrials_Cleaned_df, how="left", on=["Date", "Date"])
combined3_df = pd.merge(combined2_df, Consumer_Disc_Cleaned_df, how="left", on=["Date", "Date"])
combined4_df = pd.merge(combined3_df, Consumer_Stap_Cleaned_df, how="left", on=["Date", "Date"])
combined5_df = pd.merge(combined4_df, Health_Care_Cleaned_df, how="left", on=["Date", "Date"])
combined6_df = pd.merge(combined5_df, Financial_Cleaned_df, how="left", on=["Date", "Date"])
combined7_df = pd.merge(combined6_df, Technology_Cleaned_df, how="left", on=["Date", "Date"])
combined8_df = pd.merge(combined7_df, Communications_Cleaned_df, how="left", on=["Date", "Date"])
Combined_Sectors5_df = pd.merge(combined8_df, Utilities_Cleaned_df, how="left", on=["Date", "Date"])
Combined_Sectors5_df[["Date", "Energy Close", "Materials Close", "Industrials Close", "Consumer Disc Close", "Consumer Stap Close", "Health Care Close", "Financial Close", "Technology Close", "Communications Close", "Utilities Close"]].head()
# Out:
#          Date  Energy Close  Materials Close  Industrials Close  \
# 0  2001-02-28    228.330002       129.309998         278.459991
# 1  2001-03-01    230.169998       129.770004         275.380005
# 2  2001-03-02    235.100006       132.059998         273.309998
# 3  2001-03-05    237.570007       134.990005         276.529999
# 4  2001-03-06    238.479996       134.539993         278.429993
#
#    Consumer Disc Close  Consumer Stap Close  Health Care Close  \
# 0           248.389999           225.770004         406.899994
# 1           244.880005           224.410004         403.980011
# 2           243.580002           225.440002         404.320007
# 3           244.190002           224.259995         404.019989
# 4           249.550003           221.919998         397.649994
#
#    Financial Close  Technology Close  Communications Close  Utilities Close
# 0       368.839996        404.579987            202.630005       201.240005
# ...

# %%
# Create graphs showing the performance of each sector during the Dot Com recession.

plt.figure(figsize=(15, 40))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, sector in enumerate(sector_list, 1):
    plt.subplot(11, 2, i)
    thisyear[i-1]['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {sector_name[i - 1]}")
plt.tight_layout()
plt.savefig(f"Adj Close Change by Sectors({COVID_start.year}).png")

# %%
# Dot-Com recession:
# Create an empty list to house the closing price for each sector, the list of sector names and the date on the eve of the recession.

eve_price=[]
sectors_title=["Energy", "Materials", "Industrials", "Consumer Disc", "Consumer Stap", "Health Care", "Financial", "Technology", "Communications", "Utilities"]
eve_date_list=[]
end_date_list=[]

# %%
# Dot-Com recession:
# Extract the closing price for each sector on the eve of the recession and its corresponding date.

for sector in sectors_title:
    try:
        Price_Start = Combined_Sectors5_df[f"{sector} Close"][0]
        eve_price.append(Price_Start)
        eve_date=Combined_Sectors5_df["Date"][0]
        eve_date_list.append(eve_date)
        end_date_list.append(Dot_Com_end)
    except KeyError:
        eve_price.append("No Data")
        
# Create a dataframe for Recession Start Dates, End Dates, Sector and Sector Price (eve of recession).

Eve_Sector_df=pd.DataFrame({"Recession Start":eve_date_list, "Recession End":end_date_list, "Sector":sectors_title, "Eve Price":eve_price})
Eve_Sector_df
# Out:
#   Recession Start Recession End          Sector   Eve Price
# 0      2001-02-28    2001-11-01          Energy  228.330002
# 1      2001-02-28    2001-11-01       Materials  129.309998
# 2      2001-02-28    2001-11-01     Industrials  278.459991
# 3      2001-02-28    2001-11-01   Consumer Disc  248.389999
# 4      2001-02-28    2001-11-01   Consumer Stap  225.770004
# 5      2001-02-28    2001-11-01     Health Care  406.899994
# 6      2001-02-28    2001-11-01       Financial  368.839996
# 7      2001-02-28    2001-11-01      Technology  404.579987
# 8      2001-02-28    2001-11-01  Communications  202.630005
# 9      2001-02-28    2001-11-01       Utilities  201.240005

# %%
# Dot-Com recession:
# Examine all of the POST GFC recession data:

Dot_Com_end = datetime(2001,11,1)
Today_Date = datetime(2022,3,22)

sector_list = ['^GSPC','^SP500-40','^SP500-25','^SP500-30',"^SP500-35","^SP500-20","^SP500-45","^SP500-15","^SP500-50","^SP500-55","^GSPE"]
sector_name = ["S_P500", "Financials","Consumer_Discretionary","Consumer_Staples","Health","Industrials","Information_Tech","Materials","Tele_Services","Utilities","Energy"]
thisyear = ['^GSPC','^SP500-40','^SP500-25','^SP500-30',"^SP500-35","^SP500-20","^SP500-45","^SP500-15","^SP500-50","^SP500-55","^GSPE"]

# Extract data for each sector from Yahoo Finance and export it to its own CSV file.

for sector in sector_list: 
    file_name=str(sector)+".csv"
    thisyear[sector_list.index(sector)] = globals()[sector] = yf.download(sector, Dot_Com_end, Today_Date)
    thisyear[sector_list.index(sector)].to_csv(f"Post_Dot_Com_Recession/{file_name}", index=True, header=True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Dot-Com recession:
# Establish paths for CSV import in next step.

Energy2 = "Post_Dot_Com_Recession/^GSPE.csv"
Materials2 = "Post_Dot_Com_Recession/^SP500-15.csv"
Industrials2 = "Post_Dot_Com_Recession/^SP500-20.csv"
Consumer_Disc2 = "Post_Dot_Com_Recession/^SP500-25.csv"
Consumer_Stap2 = "Post_Dot_Com_Recession/^SP500-30.csv"
Health_Care2 = "Post_Dot_Com_Recession/^SP500-35.csv"
Financial2 = "Post_Dot_Com_Recession/^SP500-40.csv"
Technology2 = "Post_Dot_Com_Recession/^SP500-45.csv"
Communications2 = "Post_Dot_Com_Recession/^SP500-50.csv"
Utilities2 = "Post_Dot_Com_Recession/^SP500-55.csv"


# Create a data frame for each sector using its CSV file.

Energy2_df = pd.read_csv(Energy2)
Materials2_df = pd.read_csv(Materials2)
Industrials2_df = pd.read_csv(Industrials2)
Consumer_Disc2_df = pd.read_csv(Consumer_Disc2)
Consumer_Stap2_df = pd.read_csv(Consumer_Stap2)
Health_Care2_df = pd.read_csv(Health_Care2)
Financial2_df = pd.read_csv(Financial2)
Technology2_df = pd.read_csv(Technology2)
Communications2_df = pd.read_csv(Communications2)
Utilities2_df = pd.read_csv(Utilities2)


# Rename the column headers to avoid conflicts when merging data frames.

Energy2_Cleaned_df=Energy2_df.rename(columns={"Open":"Energy Open", "High": "Energy High", "Low": "Energy Low", "Close":"Energy Close", "Adj Close":"Adj Close Energy", "Volume":"Energy Volume"})
Materials2_Cleaned_df=Materials2_df.rename(columns={"Open":"Materials Open", "High": "Materials High", "Low": "Materials Low", "Close":"Materials Close", "Adj Close":"Adj Close Materials", "Volume":"Materials Volume"})
Industrials2_Cleaned_df=Industrials2_df.rename(columns={"Open":"Industrials Open", "High": "Industrials High", "Low": "Industrials Low", "Close":"Industrials Close", "Adj Close":"Adj Close Industrials", "Volume":"Industrials Volume"})
Consumer_Disc2_Cleaned_df=Consumer_Disc2_df.rename(columns={"Open":"Consumer Disc Open", "High": "Consumer Disc High", "Low": "Consumer Disc Low", "Close":"Consumer Disc Close", "Adj Close":"Adj Close Consumer Disc", "Volume":"Consumer Disc Volume"})
Consumer_Stap2_Cleaned_df=Consumer_Stap2_df.rename(columns={"Open":"Consumer Stap Open", "High": "Consumer Stap High", "Low": "Consumer Stap Low", "Close":"Consumer Stap Close", "Adj Close":"Adj Close Consumer Stap", "Volume":"Consumer Stap Volume"})
Health_Care2_Cleaned_df=Health_Care2_df.rename(columns={"Open":"Health Care Open", "High": "Health Care High", "Low": "Health Care Low", "Close":"Health Care Close", "Adj Close":"Adj Close Health Care", "Volume":"Health Care Volume"})
Financial2_Cleaned_df=Financial2_df.rename(columns={"Open":"Financial Open", "High": "Financial High", "Low": "Financial Low", "Close":"Financial Close", "Adj Close":"Adj Close Financial", "Volume":"Financial Volume"})
Technology2_Cleaned_df=Technology2_df.rename(columns={"Open":"Technology Open", "High": "Technology High", "Low": "Technology Low", "Close":"Technology Close", "Adj Close":"Adj Close Technology", "Volume":"Technology Volume"})
Communications2_Cleaned_df=Communications2_df.rename(columns={"Open":"Communications Open", "High": "Communications High", "Low": "Communications Low", "Close":"Communications Close", "Adj Close":"Adj Close Communications", "Volume":"Communications Volume"})
Utilities2_Cleaned_df=Utilities2_df.rename(columns={"Open":"Utilities Open", "High": "Utilities High", "Low": "Utilities Low", "Close":"Utilities Close", "Adj Close":"Adj Close Utilities", "Volume":"Utilities Volume"})


# Merge all sector data frames together using the DATE as the merge parameter.

combined1_df = pd.merge(Energy2_Cleaned_df, Materials2_Cleaned_df, how="left", on=["Date", "Date"])
combined2_df = pd.merge(combined1_df, Industrials2_Cleaned_df, how="left", on=["Date", "Date"])
combined3_df = pd.merge(combined2_df, Consumer_Disc2_Cleaned_df, how="left", on=["Date", "Date"])
combined4_df = pd.merge(combined3_df, Consumer_Stap2_Cleaned_df, how="left", on=["Date", "Date"])
combined5_df = pd.merge(combined4_df, Health_Care2_Cleaned_df, how="left", on=["Date", "Date"])
combined6_df = pd.merge(combined5_df, Financial2_Cleaned_df, how="left", on=["Date", "Date"])
combined7_df = pd.merge(combined6_df, Technology2_Cleaned_df, how="left", on=["Date", "Date"])
combined8_df = pd.merge(combined7_df, Communications2_Cleaned_df, how="left", on=["Date", "Date"])
Combined_Sectors6_df = pd.merge(combined8_df, Utilities2_Cleaned_df, how="left", on=["Date", "Date"])
Combined_Sectors6_df[["Date", "Energy Close", "Materials Close", "Industrials Close", "Consumer Disc Close", "Consumer Stap Close", "Health Care Close", "Financial Close", "Technology Close", "Communications Close", "Utilities Close"]].head()
# Out:
#          Date  Energy Close  Materials Close  Industrials Close  \
# 0  2001-10-31    209.520004       122.169998         233.119995
# 1  2001-11-01    213.720001       124.639999         239.449997
# 2  2001-11-02    209.020004       126.330002         242.029999
# 3  2001-11-05    207.600006       126.699997         246.350006
# 4  2001-11-06    207.029999       128.740005         249.789993
#
#    Consumer Disc Close  Consumer Stap Close  Health Care Close  \
# 0           208.070007           212.699997         380.600006
# 1           213.029999           215.830002         385.040009
# 2           215.470001           217.369995         384.170013
# 3           220.210007           218.509995         384.950012
# 4           224.710007           219.600006         387.950012
#
#    Financial Close  Technology Close  Communications Close  Utilities Close
# 0       325.549988        307.350006            162.410004       151.429993
# ...

# %%
# Create graphs showing the post Dot Com recession performance of each sector.

plt.figure(figsize=(15, 40))
plt.subplots_adjust(top=1.25, bottom=1.2)

for i, sector in enumerate(sector_list, 1):
    plt.subplot(11, 2, i)
    thisyear[i-1]['Adj Close'].plot()
    plt.ylabel('Adj Close')
    plt.xlabel(None)
    plt.title(f"Closing Price of {sector_name[i - 1]}")
plt.tight_layout()
plt.savefig(f"Adj Close Change by Sectors({COVID_start.year}).png")

# %%
# Dot-Com recession:
# Establish an empty list to house each sector's recovery date. 

recovery_dates=[]

# Analyse each sector's recovery.

# Energy:

Energy_Higher_Than_Eve_df=Combined_Sectors6_df.loc[Combined_Sectors6_df["Energy Close"]>= eve_price[0], :]
Energy_Recovery_First_Row=Energy_Higher_Than_Eve_df.iloc[0,:].tolist()
Energy_Recovery_Date=Energy_Recovery_First_Row[0]
recovery_dates.append(Energy_Recovery_Date)

# Materials

Materials_Higher_Than_Eve_df=Combined_Sectors6_df.loc[Combined_Sectors6_df["Materials Close"]>= eve_price[1], :]
Materials_Recovery_First_Row=Materials_Higher_Than_Eve_df.iloc[0,:].tolist()
Materials_Recovery_Date=Materials_Recovery_First_Row[0]
recovery_dates.append(Materials_Recovery_Date)

#Industrials

Industrials_Higher_Than_Eve_df=Combined_Sectors6_df.loc[Combined_Sectors6_df["Industrials Close"]>= eve_price[2], :]
Industrials_Recovery_First_Row=Industrials_Higher_Than_Eve_df.iloc[0,:].tolist()
Industrials_Recovery_Date=Industrials_Recovery_First_Row[0]
recovery_dates.append(Industrials_Recovery_Date)

#Consumer Disc

Consumer_Disc_Higher_Than_Eve_df=Combined_Sectors6_df.loc[Combined_Sectors6_df["Consumer Disc Close"]>= eve_price[3], :]
Consumer_Disc_Recovery_First_Row=Consumer_Disc_Higher_Than_Eve_df.iloc[0,:].tolist()
Consumer_Disc_Recovery_Date=Consumer_Disc_Recovery_First_Row[0]
recovery_dates.append(Consumer_Disc_Recovery_Date)

#Consumer Stap

Consumer_Stap_Higher_Than_Eve_df=Combined_Sectors6_df.loc[Combined_Sectors6_df["Consumer Stap Close"]>= eve_price[4], :]
Consumer_Stap_Recovery_First_Row=Consumer_Stap_Higher_Than_Eve_df.iloc[0,:].tolist()
Consumer_Stap_Recovery_Date=Consumer_Stap_Recovery_First_Row[0]
recovery_dates.append(Consumer_Stap_Recovery_Date)

# Health Care

Health_Care_Higher_Than_Eve_df=Combined_Sectors6_df.loc[Combined_Sectors6_df["Health Care Close"]>= eve_price[5], :]
Health_Care_Recovery_First_Row=Health_Care_Higher_Than_Eve_df.iloc[0,:].tolist()
Health_Care_Recovery_Date=Health_Care_Recovery_First_Row[0]
recovery_dates.append(Health_Care_Recovery_Date)

# Financial

Financial_Higher_Than_Eve_df=Combined_Sectors6_df.loc[Combined_Sectors6_df["Financial Close"]>= eve_price[6], :]
Financial_Recovery_First_Row=Financial_Higher_Than_Eve_df.iloc[0,:].tolist()
Financial_Recovery_Date=Financial_Recovery_First_Row[0]
recovery_dates.append(Financial_Recovery_Date)

# Technology

Technology_Higher_Than_Eve_df=Combined_Sectors6_df.loc[Combined_Sectors6_df["Technology Close"]>= eve_price[7], :]
Technology_Recovery_First_Row=Technology_Higher_Than_Eve_df.iloc[0,:].tolist()
Technology_Recovery_Date=Technology_Recovery_First_Row[0]
recovery_dates.append(Technology_Recovery_Date)

# Communications

Communications_Higher_Than_Eve_df=Combined_Sectors6_df.loc[Combined_Sectors6_df["Communications Close"]>= eve_price[8], :]
Communications_Recovery_First_Row=Communications_Higher_Than_Eve_df.iloc[0,:].tolist()
Communications_Recovery_Date=Communications_Recovery_First_Row[0]
recovery_dates.append(Communications_Recovery_Date)

# Utilities

Utilities_Higher_Than_Eve_df=Combined_Sectors6_df.loc[Combined_Sectors6_df["Utilities Close"]>= eve_price[9], :]
Utilities_Recovery_First_Row=Utilities_Higher_Than_Eve_df.iloc[0,:].tolist()
Utilities_Recovery_Date=Utilities_Recovery_First_Row[0]
recovery_dates.append(Utilities_Recovery_Date)

# %%
# Dot-Com recession:
# Put the recovery dates in their own data frame.

Recovery_Dates_df=pd.DataFrame({"Date":recovery_dates, "Sector":sectors_title})


# Merge the recovery dates dataframe with the Eve-Sector data frame.

Eve_to_Recovery_df=pd.merge(Eve_Sector_df, Recovery_Dates_df, on='Sector')
Eve_to_Recovery_df=Eve_to_Recovery_df.rename(columns={"Date":"Recovery Date"})


# Format all of the dates so as to remove the time.

Eve_to_Recovery_df['Recession End'] = pd.to_datetime(Eve_to_Recovery_df['Recession End']).dt.date
Eve_to_Recovery_df['Recession Start'] = pd.to_datetime(Eve_to_Recovery_df['Recession Start']).dt.date
Eve_to_Recovery_df['Recovery Date'] = pd.to_datetime(Eve_to_Recovery_df['Recovery Date']).dt.date

# %%
# Dot-Com recession:
# Determine the number of days between Recession End and Recovery Date for each sector.

Days_To_Recover_df=Eve_to_Recovery_df['Recovery Date']-Eve_to_Recovery_df['Recession End']
Eve_to_Recovery_df["Days to Recover"]=Days_To_Recover_df


# Determine the number of days between Recession Start and Recession End for each sector.

Length_Of_Recession_df=Eve_to_Recovery_df['Recession End']-Eve_to_Recovery_df['Recession Start']
Eve_to_Recovery_df["Length of Recession"]=Length_Of_Recession_df


# Express the recovery time as a percentage of the recession length for each sector.

Percentage_df=Eve_to_Recovery_df['Days to Recover']/Eve_to_Recovery_df['Length of Recession']
Eve_to_Recovery_df["QRec"]=Percentage_df
Eve_to_Recovery_df
# Out:
#   Recession Start Recession End          Sector   Eve Price Recovery Date  \
# 0      2001-02-28    2001-11-01          Energy  228.330002    2002-03-12
# 1      2001-02-28    2001-11-01       Materials  129.309998    2001-11-07
# 2      2001-02-28    2001-11-01     Industrials  278.459991    2004-11-08
# 3      2001-02-28    2001-11-01   Consumer Disc  248.389999    2002-03-04
# 4      2001-02-28    2001-11-01   Consumer Stap  225.770004    2002-02-20
# 5      2001-02-28    2001-11-01     Health Care  406.899994    2007-04-13
# 6      2001-02-28    2001-11-01       Financial  368.839996    2002-03-15
# 7      2001-02-28    2001-11-01      Technology  404.579987    2007-07-12
# 8      2001-02-28    2001-11-01  Communications  202.630005    2020-08-25
# 9      2001-02-28    2001-11-01       Utilities  201.240005    2007-03-21
#
#   Days to Recover Length of Recession       QRec
# 0        131 days            246 days   0.532520
# 1          6 days            246 days   0.024390
# ...

# %%
# Dot-Com recession:
# Create bar chart.

sectors=Eve_to_Recovery_df["Sector"].tolist()
QRec = Eve_to_Recovery_df["QRec"].tolist()

x_axis=np.arange(len(QRec))
plt.bar(x_axis, QRec, color="b", align="center")

tick_locations=[value for value in x_axis]
plt.xticks(tick_locations, sectors, rotation='vertical')

plt.xlim(-0.75, len(x_axis)-0.25)
plt.ylim(0, max(QRec)+0.5)

plt.title("Q-Rec score for each Sector after Dot-Com recession.")
plt.xlabel("Sectors")
plt.ylabel("Q-Rec Score")

plt.savefig(f"QRec by Sector ({GFC_start.year}).png")

# %%
# Dot-Com recession:
# Establish paths for CSV import in next step.

Market = "Dot_Com_Recession/^GSPC.csv"


# Create a data frame for the market using its CSV file.

Market_df = pd.read_csv(Market)


# Rename the column headers to avoid conflicts when merging data frames.

Market_Cleaned_df=Market_df.rename(columns={"Open":"Market Open", "High": "Market High", "Low": "Market Low", "Close":"Market Close", "Adj Close":"Adj Close Market", "Volume":"Market Volume"})

#Determine the Market price on the eve of the recession.

Market_Price_Eve = Market_Cleaned_df["Market Close"][0]
Market_eve_date=Market_Cleaned_df["Date"][0]
Market_Price_Eve
# Out:
# 1239.93994140625

# %%
# Dot-Com recession:
# Establish paths for CSV import in next step.

Market2 = "Post_Dot_Com_Recession/^GSPC.csv"


# Create a data frame for the market using its CSV file.

Market2_df = pd.read_csv(Market2)


# Rename the column headers to avoid conflicts when merging data frames.

Market2_Cleaned_df=Market2_df.rename(columns={"Open":"Market Open", "High": "Market High", "Low": "Market Low", "Close":"Market Close", "Adj Close":"Adj Close Market", "Volume":"Market Volume"})

# %%
# Dot-Com recession:
# Establish an empty list to house the market's recovery date. 

market_recovery_date=[]


# Analyse the market's recovery.

Market_Higher_Than_Eve_df=Market2_Cleaned_df.loc[Market2_Cleaned_df["Market Close"]>= Market_Price_Eve, :]
Market_Recovery_First_Row=Market_Higher_Than_Eve_df.iloc[0,:].tolist()
Market_Recovery_Date=Market_Recovery_First_Row[0]
Market_Recovery_Date
# Out:
# '2005-07-28'

# %%
# Dot-Com recession:
# Determine the number of days between Recession End and Recovery Date for the market.

market_recovery_date=[]
for sector in sectors_title:
    market_recovery_date.append(Market_Recovery_Date)

    
# Put the recovery dates in their own data frame.

Market_Recovery_Date_df=pd.DataFrame({"Market Recovery Date":market_recovery_date, "Sector":sectors_title})


# Merge the market recovery dates dataframe with the Eve-Sector data frame.

Eve_to_Recovery_MARKET2_df=pd.merge(Eve_to_Recovery_df, Market_Recovery_Date_df, on='Sector')


# Format all of the dates so as to remove the time.

Eve_to_Recovery_MARKET2_df['Market Recovery Date'] = pd.to_datetime(Eve_to_Recovery_MARKET2_df['Market Recovery Date']).dt.date


# Determine the number of days between Recession Start and Recovery Date for each sector.

Market_Days_To_Recover=Eve_to_Recovery_MARKET2_df['Market Recovery Date']-Eve_to_Recovery_MARKET2_df['Recession End']
Eve_to_Recovery_MARKET2_df["Market Days to Recover"]=Market_Days_To_Recover


# Express the recovery time as a percentage of the recession length for the market.

Market_QRec_df=Eve_to_Recovery_MARKET2_df['Market Days to Recover']/Eve_to_Recovery_MARKET2_df['Length of Recession']
Eve_to_Recovery_MARKET2_df["Market QRec"]=Market_QRec_df
Eve_to_Recovery_MARKET2_df
# Out:
#   Recession Start Recession End          Sector   Eve Price Recovery Date  \
# 0      2001-02-28    2001-11-01          Energy  228.330002    2002-03-12
# 1      2001-02-28    2001-11-01       Materials  129.309998    2001-11-07
# 2      2001-02-28    2001-11-01     Industrials  278.459991    2004-11-08
# 3      2001-02-28    2001-11-01   Consumer Disc  248.389999    2002-03-04
# 4      2001-02-28    2001-11-01   Consumer Stap  225.770004    2002-02-20
# 5      2001-02-28    2001-11-01     Health Care  406.899994    2007-04-13
# 6      2001-02-28    2001-11-01       Financial  368.839996    2002-03-15
# 7      2001-02-28    2001-11-01      Technology  404.579987    2007-07-12
# 8      2001-02-28    2001-11-01  Communications  202.630005    2020-08-25
# 9      2001-02-28    2001-11-01       Utilities  201.240005    2007-03-21
#
#   Days to Recover Length of Recession       QRec Market Recovery Date  \
# 0        131 days            246 days   0.532520           2005-07-28
# ...

# %%
# Dot-Com recession:
# Create bar chart for Sector QRec and Market QRec.

w=0.2
x=Eve_to_Recovery_MARKET2_df["Sector"].tolist()

QRec = Eve_to_Recovery_MARKET2_df["QRec"].tolist()
Market_QRec = Eve_to_Recovery_MARKET2_df["Market QRec"].tolist()

bar1=np.arange(len(x))
bar2=[i+w for i in bar1]

plt.bar(bar1, QRec, w, label="sector")
plt.bar(bar2, Market_QRec, w, label="market")

plt.xticks(bar1, x, rotation='vertical')

plt.xlim(-0.75, len(x)-0.25)
plt.ylim(0, max(QRec)+0.5)

plt.title("QRec and Market QRec score - Dot-Com recession.")
plt.xlabel("Sectors")
plt.ylabel("Q-Rec Score")

colors = {'Sector QRec':'royalblue', 'Market QRec':'orangered'}         
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
plt.legend(handles, labels)

plt.savefig(f"QRec and Market QRec by Sector ({Dot_Com_start.year}).png")

# %%
# Dot-Com recession:
# Create bar chart for Sector QRec and Market QRec.

w=0.2
x=Eve_to_Recovery_MARKET1_df["Sector"].tolist()

QRecDOTCOM = Eve_to_Recovery_MARKET2_df["QRec"].tolist()
QRecDOTCOM.append(0)
QRecGFC = Eve_to_Recovery_MARKET1_df["QRec"].tolist()
QRecCOVID = Eve_to_Recovery_MARKET_df["QRec"].tolist()

bar1=np.arange(len(x))
bar2=[i+w for i in bar1]
bar3=[i+2*w for i in bar1]

plt.bar(bar1, QRecGFC, w, label="GFC")
plt.bar(bar2, QRecCOVID, w, label="COVID")
plt.bar(bar3, QRecDOTCOM, w, label="DOTCOM")

plt.xticks(bar1, x, rotation='vertical')

plt.xlim(-0.75, len(x)-0.25)
plt.ylim(0, max(QRec)+5.5)

plt.title("QRec from GFC, COVID and Dot-Com Recessions.")
plt.xlabel("Sectors")
plt.ylabel("Q-Rec Score")

colors = {'GFC QRec':'royalblue', 'COVID QRec':'orangered', 'DOTCOM QRec':'orange'}         
labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]
plt.legend(handles, labels)

plt.savefig(f"QRec for GFC, COVID and DOTCOM by Sector.png")

# %%
# Create a data frame for Sabrina to analyse as her part of the project.

Sectors=Eve_to_Recovery_MARKET_df["Sector"].tolist()
COVID_QRecs=Eve_to_Recovery_MARKET_df["QRec"].tolist()
COVID_Market_QREC=Eve_to_Recovery_MARKET_df["Market QRec"].tolist()
GFC_QRECS=Eve_to_Recovery_MARKET1_df["QRec"].tolist()
GFC_Market_QREC=Eve_to_Recovery_MARKET1_df["Market QRec"].tolist()
DOTCOM_QRECS=Eve_to_Recovery_MARKET2_df["QRec"].tolist()
DOTCOM_QRECS.append(0)
DOTCOM_Market_QREC=Eve_to_Recovery_MARKET2_df["Market QRec"].tolist()
DOTCOM_Market_QREC.append(0)

QRec_df=pd.DataFrame({"Sector":Sectors, "COVID_QRecs":COVID_QRecs, "COVID_Market_QREC":COVID_Market_QREC, "GFC_QRECS":GFC_QRECS, "GFC_Market_QREC":GFC_Market_QREC, "DOTCOM_QRECS":DOTCOM_QRECS, "DOTCOM_Market_QREC":DOTCOM_Market_QREC})
QRec_df

QRec_df.to_csv(f"QRecs/QRecs.csv", index=True, header=True)

# %%
# Build a data frame which, for each sector in each recession, has the price drop and the QRec value.

Sector_Name=[]
Recession_Name=[]
Mins=[]
QRecs=[]
Maxs=[]
Days_To_Recover=[]
Min_Covid=Combined_Sectors_df["Energy Close"].min()
Mins.append(Min_Covid)
Sector_Name.append("Energy")
Recession_Name.append("COVID")
Min_GFC=Combined_Sectors3_df["Energy Close"].min()
Mins.append(Min_GFC)
Sector_Name.append("Energy")
Recession_Name.append("GFC")
Min_DOTCOM=Combined_Sectors5_df["Energy Close"].min()
Mins.append(Min_DOTCOM)
Sector_Name.append("Energy")
Recession_Name.append("DOTCOM")
Max_Covid=Combined_Sectors_df["Energy Close"].max()
Maxs.append(Max_Covid)
Max_GFC=Combined_Sectors3_df["Energy Close"].max()
Maxs.append(Max_GFC)
Max_DOTCOM=Combined_Sectors5_df["Energy Close"].max()
Maxs.append(Max_DOTCOM)
COVID_QRec=Eve_to_Recovery_MARKET_df["QRec"][0].tolist()
QRecs.append(COVID_QRec)
GFC_QRec=Eve_to_Recovery_MARKET1_df["QRec"][0].tolist()
QRecs.append(GFC_QRec)
DOTCOM_QRec=Eve_to_Recovery_MARKET2_df["QRec"][0].tolist()
QRecs.append(DOTCOM_QRec)
COVID_Days=Eve_to_Recovery_MARKET_df["Days to Recover"][0]
Days_To_Recover.append(COVID_Days)
GFC_Days=Eve_to_Recovery_MARKET1_df["Days to Recover"][0]
Days_To_Recover.append(GFC_Days)
DOTCOM_Days=Eve_to_Recovery_MARKET2_df["Days to Recover"][0]
Days_To_Recover.append(DOTCOM_Days)
Min_Covid=Combined_Sectors_df["Materials Close"].min()
Mins.append(Min_Covid)
Sector_Name.append("Materials")
Recession_Name.append("COVID")
Min_GFC=Combined_Sectors3_df["Materials Close"].min()
Mins.append(Min_GFC)
Sector_Name.append("Materials")
Recession_Name.append("GFC")
Min_DOTCOM=Combined_Sectors5_df["Materials Close"].min()
Mins.append(Min_DOTCOM)
Sector_Name.append("Materials")
Recession_Name.append("DOTCOM")
Max_Covid=Combined_Sectors_df["Materials Close"].max()
Maxs.append(Max_Covid)
Max_GFC=Combined_Sectors3_df["Materials Close"].max()
Maxs.append(Max_GFC)
Max_DOTCOM=Combined_Sectors5_df["Materials Close"].max()
Maxs.append(Max_DOTCOM)
COVID_QRec=Eve_to_Recovery_MARKET_df["QRec"][1].tolist()
QRecs.append(COVID_QRec)
GFC_QRec=Eve_to_Recovery_MARKET1_df["QRec"][1].tolist()
QRecs.append(GFC_QRec)
DOTCOM_QRec=Eve_to_Recovery_MARKET2_df["QRec"][1].tolist()
QRecs.append(DOTCOM_QRec)
COVID_Days=Eve_to_Recovery_MARKET_df["Days to Recover"][1]
Days_To_Recover.append(COVID_Days)
GFC_Days=Eve_to_Recovery_MARKET1_df["Days to Recover"][1]
Days_To_Recover.append(GFC_Days)
DOTCOM_Days=Eve_to_Recovery_MARKET2_df["Days to Recover"][1]
Days_To_Recover.append(DOTCOM_Days)
Min_Covid=Combined_Sectors_df["Industrials Close"].min()
Mins.append(Min_Covid)
Sector_Name.append("Industrials")
Recession_Name.append("COVID")
Min_GFC=Combined_Sectors3_df["Industrials Close"].min()
Mins.append(Min_GFC)
Sector_Name.append("Industrials")
Recession_Name.append("GFC")
Min_DOTCOM=Combined_Sectors5_df["Industrials Close"].min()
Mins.append(Min_DOTCOM)
Sector_Name.append("Industrials")
Recession_Name.append("DOTCOM")
Max_Covid=Combined_Sectors_df["Industrials Close"].max()
Maxs.append(Max_Covid)
Max_GFC=Combined_Sectors3_df["Industrials Close"].max()
Maxs.append(Max_GFC)
Max_DOTCOM=Combined_Sectors5_df["Industrials Close"].max()
Maxs.append(Max_DOTCOM)
COVID_QRec=Eve_to_Recovery_MARKET_df["QRec"][2].tolist()
QRecs.append(COVID_QRec)
GFC_QRec=Eve_to_Recovery_MARKET1_df["QRec"][2].tolist()
QRecs.append(GFC_QRec)
DOTCOM_QRec=Eve_to_Recovery_MARKET2_df["QRec"][2].tolist()
QRecs.append(DOTCOM_QRec)
COVID_Days=Eve_to_Recovery_MARKET_df["Days to Recover"][2]
Days_To_Recover.append(COVID_Days)
GFC_Days=Eve_to_Recovery_MARKET1_df["Days to Recover"][2]
Days_To_Recover.append(GFC_Days)
DOTCOM_Days=Eve_to_Recovery_MARKET2_df["Days to Recover"][2]
Days_To_Recover.append(DOTCOM_Days)
Min_Covid=Combined_Sectors_df["Consumer Disc Close"].min()
Mins.append(Min_Covid)
Sector_Name.append("Consumer Disc")
Recession_Name.append("COVID")
Min_GFC=Combined_Sectors3_df["Consumer Disc Close"].min()
Mins.append(Min_GFC)
Sector_Name.append("Consumer Disc")
Recession_Name.append("GFC")
Min_DOTCOM=Combined_Sectors5_df["Consumer Disc Close"].min()
Mins.append(Min_DOTCOM)
Sector_Name.append("Consumer Disc")
Recession_Name.append("DOTCOM")
Max_Covid=Combined_Sectors_df["Consumer Disc Close"].max()
Maxs.append(Max_Covid)
Max_GFC=Combined_Sectors3_df["Consumer Disc Close"].max()
Maxs.append(Max_GFC)
Max_DOTCOM=Combined_Sectors5_df["Consumer Disc Close"].max()
Maxs.append(Max_DOTCOM)
COVID_QRec=Eve_to_Recovery_MARKET_df["QRec"][3].tolist()
QRecs.append(COVID_QRec)
GFC_QRec=Eve_to_Recovery_MARKET1_df["QRec"][3].tolist()
QRecs.append(GFC_QRec)
DOTCOM_QRec=Eve_to_Recovery_MARKET2_df["QRec"][3].tolist()
QRecs.append(DOTCOM_QRec)
COVID_Days=Eve_to_Recovery_MARKET_df["Days to Recover"][3]
Days_To_Recover.append(COVID_Days)
GFC_Days=Eve_to_Recovery_MARKET1_df["Days to Recover"][3]
Days_To_Recover.append(GFC_Days)
DOTCOM_Days=Eve_to_Recovery_MARKET2_df["Days to Recover"][3]
Days_To_Recover.append(DOTCOM_Days)
Min_Covid=Combined_Sectors_df["Consumer Stap Close"].min()
Mins.append(Min_Covid)
Sector_Name.append("Consumer Stap")
Recession_Name.append("COVID")
Min_GFC=Combined_Sectors3_df["Consumer Stap Close"].min()
Mins.append(Min_GFC)
Sector_Name.append("Consumer Stap")
Recession_Name.append("GFC")
Min_DOTCOM=Combined_Sectors5_df["Consumer Stap Close"].min()
Mins.append(Min_DOTCOM)
Sector_Name.append("Consumer Stap")
Recession_Name.append("DOTCOM")
Max_Covid=Combined_Sectors_df["Consumer Stap Close"].max()
Maxs.append(Max_Covid)
Max_GFC=Combined_Sectors3_df["Consumer Stap Close"].max()
Maxs.append(Max_GFC)
Max_DOTCOM=Combined_Sectors5_df["Consumer Stap Close"].max()
Maxs.append(Max_DOTCOM)
COVID_QRec=Eve_to_Recovery_MARKET_df["QRec"][4].tolist()
QRecs.append(COVID_QRec)
GFC_QRec=Eve_to_Recovery_MARKET1_df["QRec"][4].tolist()
QRecs.append(GFC_QRec)
DOTCOM_QRec=Eve_to_Recovery_MARKET2_df["QRec"][4].tolist()
QRecs.append(DOTCOM_QRec)
COVID_Days=Eve_to_Recovery_MARKET_df["Days to Recover"][4]
Days_To_Recover.append(COVID_Days)
GFC_Days=Eve_to_Recovery_MARKET1_df["Days to Recover"][4]
Days_To_Recover.append(GFC_Days)
DOTCOM_Days=Eve_to_Recovery_MARKET2_df["Days to Recover"][4]
Days_To_Recover.append(DOTCOM_Days)
Min_Covid=Combined_Sectors_df["Health Care Close"].min()
Mins.append(Min_Covid)
Sector_Name.append("Health Care")
Recession_Name.append("COVID")
Min_GFC=Combined_Sectors3_df["Health Care Close"].min()
Mins.append(Min_GFC)
Sector_Name.append("Health Care")
Recession_Name.append("GFC")
Min_DOTCOM=Combined_Sectors5_df["Health Care Close"].min()
Mins.append(Min_DOTCOM)
Sector_Name.append("Health Care")
Recession_Name.append("DOTCOM")
Max_Covid=Combined_Sectors_df["Health Care Close"].max()
Maxs.append(Max_Covid)
Max_GFC=Combined_Sectors3_df["Health Care Close"].max()
Maxs.append(Max_GFC)
Max_DOTCOM=Combined_Sectors5_df["Health Care Close"].max()
Maxs.append(Max_DOTCOM)
COVID_QRec=Eve_to_Recovery_MARKET_df["QRec"][5].tolist()
QRecs.append(COVID_QRec)
GFC_QRec=Eve_to_Recovery_MARKET1_df["QRec"][5].tolist()
QRecs.append(GFC_QRec)
DOTCOM_QRec=Eve_to_Recovery_MARKET2_df["QRec"][5].tolist()
QRecs.append(DOTCOM_QRec)
COVID_Days=Eve_to_Recovery_MARKET_df["Days to Recover"][5]
Days_To_Recover.append(COVID_Days)
GFC_Days=Eve_to_Recovery_MARKET1_df["Days to Recover"][5]
Days_To_Recover.append(GFC_Days)
DOTCOM_Days=Eve_to_Recovery_MARKET2_df["Days to Recover"][5]
Days_To_Recover.append(DOTCOM_Days)
Min_Covid=Combined_Sectors_df["Financial Close"].min()
Mins.append(Min_Covid)
Sector_Name.append("Financial")
Recession_Name.append("COVID")
Min_GFC=Combined_Sectors3_df["Financial Close"].min()
Mins.append(Min_GFC)
Sector_Name.append("Financial")
Recession_Name.append("GFC")
Min_DOTCOM=Combined_Sectors5_df["Financial Close"].min()
Mins.append(Min_DOTCOM)
Sector_Name.append("Financial")
Recession_Name.append("DOTCOM")
Max_Covid=Combined_Sectors_df["Financial Close"].max()
Maxs.append(Max_Covid)
Max_GFC=Combined_Sectors3_df["Financial Close"].max()
Maxs.append(Max_GFC)
Max_DOTCOM=Combined_Sectors5_df["Financial Close"].max()
Maxs.append(Max_DOTCOM)
COVID_QRec=Eve_to_Recovery_MARKET_df["QRec"][6].tolist()
QRecs.append(COVID_QRec)
GFC_QRec=Eve_to_Recovery_MARKET1_df["QRec"][6].tolist()
QRecs.append(GFC_QRec)
DOTCOM_QRec=Eve_to_Recovery_MARKET2_df["QRec"][6].tolist()
QRecs.append(DOTCOM_QRec)
COVID_Days=Eve_to_Recovery_MARKET_df["Days to Recover"][6]
Days_To_Recover.append(COVID_Days)
GFC_Days=Eve_to_Recovery_MARKET1_df["Days to Recover"][6]
Days_To_Recover.append(GFC_Days)
DOTCOM_Days=Eve_to_Recovery_MARKET2_df["Days to Recover"][6]
Days_To_Recover.append(DOTCOM_Days)
Min_Covid=Combined_Sectors_df["Technology Close"].min()
Mins.append(Min_Covid)
Sector_Name.append("Technology")
Recession_Name.append("COVID")
Min_GFC=Combined_Sectors3_df["Technology Close"].min()
Mins.append(Min_GFC)
Sector_Name.append("Technology")
Recession_Name.append("GFC")
Min_DOTCOM=Combined_Sectors5_df["Technology Close"].min()
Mins.append(Min_DOTCOM)
Sector_Name.append("Technology")
Recession_Name.append("DOTCOM")
Max_Covid=Combined_Sectors_df["Technology Close"].max()
Maxs.append(Max_Covid)
Max_GFC=Combined_Sectors3_df["Technology Close"].max()
Maxs.append(Max_GFC)
Max_DOTCOM=Combined_Sectors5_df["Technology Close"].max()
Maxs.append(Max_DOTCOM)
COVID_QRec=Eve_to_Recovery_MARKET_df["QRec"][7].tolist()
QRecs.append(COVID_QRec)
GFC_QRec=Eve_to_Recovery_MARKET1_df["QRec"][7].tolist()
QRecs.append(GFC_QRec)
DOTCOM_QRec=Eve_to_Recovery_MARKET2_df["QRec"][7].tolist()
QRecs.append(DOTCOM_QRec)
COVID_Days=Eve_to_Recovery_MARKET_df["Days to Recover"][7]
Days_To_Recover.append(COVID_Days)
GFC_Days=Eve_to_Recovery_MARKET1_df["Days to Recover"][7]
Days_To_Recover.append(GFC_Days)
DOTCOM_Days=Eve_to_Recovery_MARKET2_df["Days to Recover"][7]
Days_To_Recover.append(DOTCOM_Days)
Min_Covid=Combined_Sectors_df["Communications Close"].min()
Mins.append(Min_Covid)
Sector_Name.append("Communications")
Recession_Name.append("COVID")
Min_GFC=Combined_Sectors3_df["Communications Close"].min()
Mins.append(Min_GFC)
Sector_Name.append("Communications")
Recession_Name.append("GFC")
Min_DOTCOM=Combined_Sectors5_df["Communications Close"].min()
Mins.append(Min_DOTCOM)
Sector_Name.append("Communications")
Recession_Name.append("DOTCOM")
Max_Covid=Combined_Sectors_df["Communications Close"].max()
Maxs.append(Max_Covid)
Max_GFC=Combined_Sectors3_df["Communications Close"].max()
Maxs.append(Max_GFC)
Max_DOTCOM=Combined_Sectors5_df["Communications Close"].max()
Maxs.append(Max_DOTCOM)
COVID_QRec=Eve_to_Recovery_MARKET_df["QRec"][8].tolist()
QRecs.append(COVID_QRec)
GFC_QRec=Eve_to_Recovery_MARKET1_df["QRec"][8].tolist()
QRecs.append(GFC_QRec)
DOTCOM_QRec=Eve_to_Recovery_MARKET2_df["QRec"][8].tolist()
QRecs.append(DOTCOM_QRec)
COVID_Days=Eve_to_Recovery_MARKET_df["Days to Recover"][8]
Days_To_Recover.append(COVID_Days)
GFC_Days=Eve_to_Recovery_MARKET1_df["Days to Recover"][8]
Days_To_Recover.append(GFC_Days)
DOTCOM_Days=Eve_to_Recovery_MARKET2_df["Days to Recover"][8]
Days_To_Recover.append(DOTCOM_Days)
Min_Covid=Combined_Sectors_df["Utilities Close"].min()
Mins.append(Min_Covid)
Sector_Name.append("Utilities")
Recession_Name.append("COVID")
Min_GFC=Combined_Sectors3_df["Utilities Close"].min()
Mins.append(Min_GFC)
Sector_Name.append("Utilities")
Recession_Name.append("GFC")
Min_DOTCOM=Combined_Sectors5_df["Utilities Close"].min()
Mins.append(Min_DOTCOM)
Sector_Name.append("Utilities")
Recession_Name.append("DOTCOM")
Max_Covid=Combined_Sectors_df["Utilities Close"].max()
Maxs.append(Max_Covid)
Max_GFC=Combined_Sectors3_df["Utilities Close"].max()
Maxs.append(Max_GFC)
Max_DOTCOM=Combined_Sectors5_df["Utilities Close"].max()
Maxs.append(Max_DOTCOM)
COVID_QRec=Eve_to_Recovery_MARKET_df["QRec"][9].tolist()
QRecs.append(COVID_QRec)
GFC_QRec=Eve_to_Recovery_MARKET1_df["QRec"][9].tolist()
QRecs.append(GFC_QRec)
DOTCOM_QRec=Eve_to_Recovery_MARKET2_df["QRec"][9].tolist()
QRecs.append(DOTCOM_QRec)
COVID_Days=Eve_to_Recovery_MARKET_df["Days to Recover"][9]
Days_To_Recover.append(COVID_Days)
GFC_Days=Eve_to_Recovery_MARKET1_df["Days to Recover"][9]
Days_To_Recover.append(GFC_Days)
DOTCOM_Days=Eve_to_Recovery_MARKET2_df["Days to Recover"][9]
Days_To_Recover.append(DOTCOM_Days)
Min_Covid=Combined_Sectors_df["Real Estate Close"].min()
Mins.append(Min_Covid)
Sector_Name.append("Real Estate")
Recession_Name.append("COVID")
Min_GFC=Combined_Sectors3_df["Real Estate Close"].min()
Mins.append(Min_GFC)
Sector_Name.append("Real Estate")
Recession_Name.append("GFC")
Max_Covid=Combined_Sectors_df["Real Estate Close"].max()
Maxs.append(Max_Covid)
Max_GFC=Combined_Sectors3_df["Real Estate Close"].max()
Maxs.append(Max_GFC)
COVID_QRec=Eve_to_Recovery_MARKET_df["QRec"][10].tolist()
QRecs.append(COVID_QRec)
GFC_QRec=Eve_to_Recovery_MARKET1_df["QRec"][10].tolist()
QRecs.append(GFC_QRec)
COVID_Days=Eve_to_Recovery_MARKET_df["Days to Recover"][10]
Days_To_Recover.append(COVID_Days)
GFC_Days=Eve_to_Recovery_MARKET1_df["Days to Recover"][10]
Days_To_Recover.append(GFC_Days)

master_df=pd.DataFrame({"Sector":Sector_Name, "Recession":Recession_Name, "Max Price":Maxs, "Min Price":Mins, "QRec":QRecs})
change_in_price= master_df["Max Price"]-master_df["Min Price"]
master_df["Change"]=change_in_price
Percentage_change_in_price=100*master_df["Change"]/master_df["Max Price"]
master_df["% Change"]=Percentage_change_in_price
# master_df.reset_index(drop=True, inplace=True)
master_df
# Out:
#             Sector Recession    Max Price    Min Price       QRec      Change  \
# 0           Energy     COVID   415.970001   179.940002   6.737705  236.029999
# 1           Energy       GFC   668.809998   304.809998   1.134791  364.000000
# 2           Energy    DOTCOM   254.660004   186.929993   0.532520   67.730011
# 3        Materials     COVID   383.179993   241.669998   1.032787  141.509995
# 4        Materials       GFC   285.910004   108.330002   2.633880  177.580002
# 5        Materials    DOTCOM   150.990005   109.440002   0.024390   41.550003
# 6      Industrials     COVID   718.210022   412.059998   3.180328  306.150024
# 7      Industrials       GFC   365.619995   132.830002   2.475410  232.789993
# 8      Industrials    DOTCOM   310.809998   203.509995   4.483740  107.300003
# 9    Consumer Disc     COVID  1048.280029   707.130005   0.901639  341.150024
# 10   Consumer Disc       GFC   274.489990   125.720001   0.577413  148.769989
# ...

# %%
time_df=pd.DataFrame({"Days to Recover":Days_To_Recover})

# master_merged_df = pd.merge(master_df, time_df, left_index=True)
# master_merged_df

# %%
# For each sector in each recession, create a scatterplot of QRec versus % Price Drop

from scipy.stats import linregress
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json as json
import csv as csv
from sklearn import datasets

y_values = master_df['QRec'].astype(int)
x_values = master_df['% Change'].astype(int)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(80,20),fontsize=11,color="red")
plt.title(f"QRec Vs % Price Drop ")
plt.xlabel('% Price Drop')
plt.ylabel('QRec')
print(f"The r-squared is: {rvalue**2}")
plt.xlim(-5, 105)
plt.ylim(-5, 30)
plt.show()
print("For Linear Regression Line:")
print("(y is the QRec and x is the % Price Drop.)")
# Out:
# The r-squared is: 0.015831200543271477
# For Linear Regression Line:
# (y is the QRec and x is the % Price Drop.)

# %%
# For each sector in each recession, create a scatterplot of QRec versus % Price Drop

from scipy.stats import linregress
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json as json
import csv as csv
from sklearn import datasets

y_values = [411, 623, 131, 63, 1446, 6, 194, 1359, 1103, 55, 317, 123, 125, 563, 111, 16, 1016, 1989, 280, 2830, 134, 40, 560, 2079, 62, 1409, 6872, 503, 1779, 1966, 348, 1142]
x_values = master_df['% Change'].astype(int)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(70,5000),fontsize=11,color="red")
plt.title(f"Recover Time (days) Vs % Price Drop ")
plt.xlabel('% Price Drop')
plt.ylabel('Recover Time (days)')
print(f"The r-squared is: {rvalue**2}")
plt.xlim(-5, 105)
plt.ylim(-1000, 7500)
plt.show()
print("For Linear Regression Line:")
print("(y is the Days to Recover and x is the % Price Drop.)")
# Out:
# The r-squared is: 0.007289653075347087
# For Linear Regression Line:
# (y is the Days to Recover and x is the % Price Drop.)

# %%
Eve_to_Recovery_df
# Out:
#   Recession Start Recession End          Sector   Eve Price Recovery Date  \
# 0      2001-02-28    2001-11-01          Energy  228.330002    2002-03-12
# 1      2001-02-28    2001-11-01       Materials  129.309998    2001-11-07
# 2      2001-02-28    2001-11-01     Industrials  278.459991    2004-11-08
# 3      2001-02-28    2001-11-01   Consumer Disc  248.389999    2002-03-04
# 4      2001-02-28    2001-11-01   Consumer Stap  225.770004    2002-02-20
# 5      2001-02-28    2001-11-01     Health Care  406.899994    2007-04-13
# 6      2001-02-28    2001-11-01       Financial  368.839996    2002-03-15
# 7      2001-02-28    2001-11-01      Technology  404.579987    2007-07-12
# 8      2001-02-28    2001-11-01  Communications  202.630005    2020-08-25
# 9      2001-02-28    2001-11-01       Utilities  201.240005    2007-03-21
#
#   Days to Recover Length of Recession       QRec
# 0        131 days            246 days   0.532520
# 1          6 days            246 days   0.024390
# ...

# %%
Eve_to_Recovery_df['QRec']= round(Eve_to_Recovery_df['QRec'],2)
Eve_to_Recovery_df
# Out:
#   Recession Start Recession End          Sector   Eve Price Recovery Date  \
# 0      2001-02-28    2001-11-01          Energy  228.330002    2002-03-12
# 1      2001-02-28    2001-11-01       Materials  129.309998    2001-11-07
# 2      2001-02-28    2001-11-01     Industrials  278.459991    2004-11-08
# 3      2001-02-28    2001-11-01   Consumer Disc  248.389999    2002-03-04
# 4      2001-02-28    2001-11-01   Consumer Stap  225.770004    2002-02-20
# 5      2001-02-28    2001-11-01     Health Care  406.899994    2007-04-13
# 6      2001-02-28    2001-11-01       Financial  368.839996    2002-03-15
# 7      2001-02-28    2001-11-01      Technology  404.579987    2007-07-12
# 8      2001-02-28    2001-11-01  Communications  202.630005    2020-08-25
# 9      2001-02-28    2001-11-01       Utilities  201.240005    2007-03-21
#
#   Days to Recover Length of Recession   QRec
# 0        131 days            246 days   0.53
# 1          6 days            246 days   0.02
# ...

# %%
Eve_to_Recovery_df.dtypes
# Out:
# Recession Start                 object
# Recession End                   object
# Sector                          object
# Eve Price                      float64
# Recovery Date                   object
# Days to Recover        timedelta64[ns]
# Length of Recession    timedelta64[ns]
# QRec                           float64
# dtype: object

# %%
list = round(Eve_to_Recovery_df['QRec'],2)
list = list.sort_values()
list
# Out:
# 1     0.02
# 4     0.45
# 3     0.50
# 0     0.53
# 6     0.54
# 2     4.48
# 9     7.99
# 5     8.09
# 7     8.45
# 8    27.93
# Name: QRec, dtype: float64

# %%
other_QRec_sum = (list[1:5]).sum()
other_QRec_sum
# Out:
# 2.02

# %%
float(list[6])
# Out:
# 0.54

# %%
# QRec Pie chart for Covid

# Labels for the sections of our pie chart
labels = Eve_to_Recovery_df["Sector"]

# The values of each section of the pie chart
sizes = Eve_to_Recovery_df["QRec"]

# Creates the pie chart based upon the values above

plt.rc('font', size=10) 
plt.pie(sizes,labels=labels,autopct="%1.1f%%", shadow=True, startangle=120)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc544136610>,
# ...
#  [Text(-0.5766705873555912, 0.936723563106511, 'Energy'),
#   Text(-0.6038614344716988, 0.9194299146524341, 'Materials'),
#   Text(-0.8048752630400801, 0.7497838428148221, 'Industrials'),
#   Text(-0.9732885703835851, 0.5125518108061636, 'Consumer Disc'),
#   Text(-0.9979678889439934, 0.4626662864707884, 'Consumer Stap'),
#   Text(-1.0997626596960233, -0.02284933999767275, 'Health Care'),
#   Text(-0.9754637069774424, -0.5083999964298057, 'Financial'),
#   Text(-0.6314937198386266, -0.9006751255610285, 'Technology'),
#   Text(1.067287595934566, -0.2662652578993637, 'Communications'),
#   Text(-0.10763728916307477, 1.094721066747884, 'Utilities')],
#  [Text(-0.3145475931030497, 0.5109401253308241, '0.9%'),
#   Text(-0.32937896425729024, 0.5015072261740549, '0.0%'),
#   Text(-0.43902287074913454, 0.40897300517172114, '7.6%'),
#   Text(-0.5308846747546827, 0.27957371498518013, '0.8%'),
# ...

# %%
# QRec Pie chart for GFC

# Labels for the sections of our pie chart
labels1 = Eve_to_Recovery_MARKET1_df["Sector"]

# The values of each section of the pie chart
sizes1 = Eve_to_Recovery_MARKET1_df["QRec"]

# Creates the pie chart based upon the values above
plt.pie(sizes1,labels=labels1,autopct="%1.1f%%", shadow=True, startangle=120)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc54483f6a0>,
# ...
#  [Text(-0.6862233818133013, 0.8597077818961023, 'Energy'),
#   Text(-1.013663026869099, 0.42718528527862076, 'Materials'),
#   Text(-1.0581488402926038, -0.30053457669196393, 'Industrials'),
#   Text(-0.8550606274318613, -0.6920052914651968, 'Consumer Disc'),
#   Text(-0.6903565960147642, -0.8563922993225171, 'Consumer Stap'),
#   Text(-0.32314561445495277, -1.0514641752615879, 'Health Care'),
#   Text(0.6463922349079968, -0.8900433015593372, 'Financial'),
#   Text(1.0912516236395384, -0.13845538596989002, 'Technology'),
#   Text(1.0340540025233373, 0.3751430658634997, 'Communications'),
#   Text(0.4833668601042907, 0.9881075237811517, 'Utilities'),
#   Text(-0.27060163671402876, 1.0661963957018843, 'Real Estate')],
#  [Text(-0.37430366280725524, 0.4689315173978739, '4.8%'),
#   Text(-0.552907105564963, 0.23301015560652039, '11.1%'),
#   Text(-0.5771720947050565, -0.1639279509228894, '10.4%'),
# ...

# %%
# QRec Pie chart for GFC

# Labels for the sections of our pie chart
labels1 = Eve_to_Recovery_MARKET1_df["Sector"]

# The values of each section of the pie chart
sizes1 = Eve_to_Recovery_MARKET1_df["QRec"]

# Creates the pie chart based upon the values above
plt.pie(sizes1,labels=labels1,autopct="%1.1f%%", shadow=True, startangle=120)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc5448cf790>,
# ...
#  [Text(-0.6862233818133013, 0.8597077818961023, 'Energy'),
#   Text(-1.013663026869099, 0.42718528527862076, 'Materials'),
#   Text(-1.0581488402926038, -0.30053457669196393, 'Industrials'),
#   Text(-0.8550606274318613, -0.6920052914651968, 'Consumer Disc'),
#   Text(-0.6903565960147642, -0.8563922993225171, 'Consumer Stap'),
#   Text(-0.32314561445495277, -1.0514641752615879, 'Health Care'),
#   Text(0.6463922349079968, -0.8900433015593372, 'Financial'),
#   Text(1.0912516236395384, -0.13845538596989002, 'Technology'),
#   Text(1.0340540025233373, 0.3751430658634997, 'Communications'),
#   Text(0.4833668601042907, 0.9881075237811517, 'Utilities'),
#   Text(-0.27060163671402876, 1.0661963957018843, 'Real Estate')],
#  [Text(-0.37430366280725524, 0.4689315173978739, '4.8%'),
#   Text(-0.552907105564963, 0.23301015560652039, '11.1%'),
#   Text(-0.5771720947050565, -0.1639279509228894, '10.4%'),
# ...

# %%
# QRec Pie chart for DOTCOM

# Labels for the sections of our pie chart
labels2 = Eve_to_Recovery_MARKET2_df["Sector"]

# The values of each section of the pie chart
sizes2 = Eve_to_Recovery_MARKET2_df["QRec"]

# Creates the pie chart based upon the values above
plt.pie(sizes2,labels=labels2,autopct="%1.1f%%", shadow=True, startangle=120)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc527b78250>,
# ...
#  [Text(-0.5767873284604552, 0.9366516843135719, 'Energy'),
#   Text(-0.6043051465081132, 0.9191383410041212, 'Materials'),
#   Text(-0.8055005320184908, 0.7491120696650991, 'Industrials'),
#   Text(-0.9737717318247697, 0.5116332810705231, 'Consumer Disc'),
#   Text(-0.9984260324380427, 0.4616767892693206, 'Consumer Stap'),
#   Text(-1.0997474519024324, -0.023569939204569547, 'Health Care'),
#   Text(-0.9752074971066602, -0.5088912826792805, 'Financial'),
#   Text(-0.6309015154346018, -0.901090049785438, 'Technology'),
#   Text(1.0673752046580254, -0.2659138440947344, 'Communications'),
#   Text(-0.10768557169661881, 1.0947163183438768, 'Utilities')],
#  [Text(-0.31461127006933914, 0.5109009187164938, '0.9%'),
#   Text(-0.3296209890044253, 0.5013481860022478, '0.0%'),
#   Text(-0.4393639265555404, 0.40860658345369044, '7.6%'),
#   Text(-0.5311482173589652, 0.27907269876573987, '0.8%'),
# ...

# %%
averageQRec_df=Eve_to_Recovery_df.copy()
averageQRec_df.head()
# Out:
#   Recession Start Recession End         Sector   Eve Price Recovery Date  \
# 0      2001-02-28    2001-11-01         Energy  228.330002    2002-03-12
# 1      2001-02-28    2001-11-01      Materials  129.309998    2001-11-07
# 2      2001-02-28    2001-11-01    Industrials  278.459991    2004-11-08
# 3      2001-02-28    2001-11-01  Consumer Disc  248.389999    2002-03-04
# 4      2001-02-28    2001-11-01  Consumer Stap  225.770004    2002-02-20
#
#   Days to Recover Length of Recession  QRec
# 0        131 days            246 days  0.53
# 1          6 days            246 days  0.02
# 2       1103 days            246 days  4.48
# 3        123 days            246 days  0.50
# 4        111 days            246 days  0.45

# %%
Eve_to_Recovery_df.head()
len(Eve_to_Recovery_df)
# Out:
# 10

# %%
Eve_to_Recovery_MARKET1_df.head()
# Out:
#   Recession Start Recession End         Sector   Eve Price Recovery Date  \
# 0      2007-11-30    2009-06-01         Energy  562.130005    2011-02-14
# 1      2007-11-30    2009-06-01      Materials  257.589996    2013-05-17
# 2      2007-11-30    2009-06-01    Industrials  357.470001    2013-02-19
# 3      2007-11-30    2009-06-01  Consumer Disc  273.029999    2010-04-14
# 4      2007-11-30    2009-06-01  Consumer Stap  303.329987    2010-12-16
#
#   Days to Recover Length of Recession      QRec Market Recovery Date  \
# 0        623 days            549 days  1.134791           2013-01-18
# 1       1446 days            549 days  2.633880           2013-01-18
# 2       1359 days            549 days  2.475410           2013-01-18
# 3        317 days            549 days  0.577413           2013-01-18
# 4        563 days            549 days  1.025501           2013-01-18
#
#   Market Days to Recover  Market QRec
# 0              1327 days     2.417122
# ...

# %%
len(Eve_to_Recovery_MARKET1_df)
# Out:
# 11

# %%
Eve_to_Recovery_MARKET_df.head()
# Out:
#   Recession Start Recession End         Sector   Eve Price Recovery Date  \
# 0      2020-01-31    2020-04-01         Energy  405.450012    2021-05-17
# 1      2020-01-31    2020-04-01      Materials  361.989990    2020-06-03
# 2      2020-01-31    2020-04-01    Industrials  684.119995    2020-10-12
# 3      2020-01-31    2020-04-01  Consumer Disc  992.010010    2020-05-26
# 4      2020-01-31    2020-04-01  Consumer Stap  648.250000    2020-08-04
#
#   Days to Recover Length of Recession      QRec Market Recovery Date  \
# 0        411 days             61 days  6.737705           2020-06-08
# 1         63 days             61 days  1.032787           2020-06-08
# 2        194 days             61 days  3.180328           2020-06-08
# 3         55 days             61 days  0.901639           2020-06-08
# 4        125 days             61 days  2.049180           2020-06-08
#
#   Market Days to Recover  Market QRec
# 0                68 days     1.114754
# ...

# %%
len(Eve_to_Recovery_MARKET_df)
# Out:
# 11

# %%
Eve_to_Recovery_MARKET2_df.head()
# Out:
#   Recession Start Recession End         Sector   Eve Price Recovery Date  \
# 0      2001-02-28    2001-11-01         Energy  228.330002    2002-03-12
# 1      2001-02-28    2001-11-01      Materials  129.309998    2001-11-07
# 2      2001-02-28    2001-11-01    Industrials  278.459991    2004-11-08
# 3      2001-02-28    2001-11-01  Consumer Disc  248.389999    2002-03-04
# 4      2001-02-28    2001-11-01  Consumer Stap  225.770004    2002-02-20
#
#   Days to Recover Length of Recession     QRec Market Recovery Date  \
# 0        131 days            246 days  0.53252           2005-07-28
# 1          6 days            246 days  0.02439           2005-07-28
# 2       1103 days            246 days  4.48374           2005-07-28
# 3        123 days            246 days  0.50000           2005-07-28
# 4        111 days            246 days  0.45122           2005-07-28
#
#   Market Days to Recover  Market QRec
# 0              1365 days      5.54878
# 1              1365 days      5.54878
# ...

# %%
len(Eve_to_Recovery_MARKET2_df)
# Out:
# 10

# %%
averageQRec_df['QRec']= (Eve_to_Recovery_df['QRec']+Eve_to_Recovery_MARKET1_df['QRec']+Eve_to_Recovery_MARKET_df['QRec']
    +Eve_to_Recovery_MARKET2_df['QRec'])/4

averageQRec_df.head()
# Out:
#   Recession Start Recession End         Sector   Eve Price Recovery Date  \
# 0      2001-02-28    2001-11-01         Energy  228.330002    2002-03-12
# 1      2001-02-28    2001-11-01      Materials  129.309998    2001-11-07
# 2      2001-02-28    2001-11-01    Industrials  278.459991    2004-11-08
# 3      2001-02-28    2001-11-01  Consumer Disc  248.389999    2002-03-04
# 4      2001-02-28    2001-11-01  Consumer Stap  225.770004    2002-02-20
#
#   Days to Recover Length of Recession      QRec
# 0        131 days            246 days  2.233754
# 1          6 days            246 days  0.927764
# 2       1103 days            246 days  3.654869
# 3        123 days            246 days  0.619763
# 4        111 days            246 days  0.993975

# %%
x=averageQRec_df["Sector"].tolist()

Ave_QRec = averageQRec_df['QRec'].tolist()
bar1=np.arange(len(x))

plt.bar(bar1,Ave_QRec, color='r', alpha=0.5)
plt.xticks(bar1, x, rotation='vertical')

# plt.xlim(-0.75, len(x)-0.25)
# plt.ylim(0, max(QRec)+5.5)
plt.title("Average Qrec across all recessions")
plt.xlabel("Sectors")
plt.ylabel("Q-Rec Score")
plt.show()
